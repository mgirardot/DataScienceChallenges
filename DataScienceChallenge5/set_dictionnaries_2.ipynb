# %%
import sys
import os
import nltk
import re
import unicodedata

# %%
def parse_dictionnaries(dictionnaries_folder):
    filenames = os.listdir(dictionnaries_folder)
    #create a dict of all languages
    languages_index = dict()
    languages_dict = dict()
    for i,filename in enumerate(filenames):
        l = filename.split('.')[0]
        languages_index[i] = l
        
        #open text
        with open(os.path.relpath(os.path.join(dictionnaries_folder, filename)))  as f:
            data = f.read()
        
        #normalize text
        ascii_data = unicodedata.normalize('NFKD',unicode(data,"utf-8")).strip().encode('ASCII','ignore')
        
        #tokenize
        re_tok = nltk.tokenize.RegexpTokenizer(r"\w+")
        punct_tokens = re_tok.tokenize(ascii_data)
        
        #lower case and exclude numbers
        lower_tokens = [w.lower() for w in punct_tokens if w.isalpha() ]
        
        #unique set of words
        set_words = list(sorted(set(lower_tokens)))
        
        #filter on size
        sel_set_words = [w for w in set_words if (len(w) > 2)]
        
        #store the list of words in its dict entry
        languages_dict[l] = sel_set_words
        
    return languages_index, languages_dict

# %%
languages_index, languages_dict = parse_dictionnaries("books/")

# %%
languages_index
# Out:
# {0: 'afrikaans',
#  1: 'arapaho',
#  2: 'breton',
#  3: 'calo',
#  4: 'catalan',
#  5: 'cebuano',
#  6: 'czech',
#  7: 'danish',
#  8: 'dutch',
#  9: 'english',
#  10: 'esperanto',
#  11: 'estonian',
#  12: 'finnish',
#  13: 'french',
#  14: 'frisian',
#  15: 'friulian',
#  16: 'gaelic',
#  17: 'galician',
#  18: 'german',
#  19: 'hugarian',
#  20: 'icelandic',
#  21: 'interlingua',
#  22: 'inuktitut',
#  23: 'irish',
#  24: 'italian',
#  25: 'kashubian',
#  26: 'latin',
#  27: 'lloko',
#  28: 'maori',
#  29: 'mayan',
#  30: 'north-american-indian',
#  31: 'norwegian',
#  32: 'occitan',
#  33: 'polish',
#  34: 'portugese',
#  35: 'romanian',
#  36: 'sanskrit',
#  37: 'slovenian',
#  38: 'spanish',
#  39: 'swedish',
#  40: 'tagalog',
#  41: 'welsh'}

# %%
languages_dict
# Out:
# {'afrikaans': ['aakligheid',
#   'aambeeldklanke',
#   'aambeibossie',
#   'aan',
#   'aanbeveel',
#   'aanbidder',
#   'aanbidders',
#   'aanbidding',
#   'aanbied',
#   'aanblik',
#   'aanbod',
#   'aanbreek',
#   'aanbrengen',
#   'aanbrenging',
#   'aanbrengt',
#   'aanbring',
#   'aand',
#   'aandacht',
#   'aandag',
#   'aande',
#   'aandeel',
#   'aandete',
#   'aandoening',
#   'aandoeningloos',
#   'aandoenlik',
#   'aandra',
#   'aandrang',
#   'aandrif',
#   'aandring',
#   'aandskemering',
#   'aandskoonheid',
#   'aandui',
#   'aanduiding',
#   'aanduidings',
#   'aaneenryging',
#   'aaneenskakeling',
#   'aaneenstrengeling',
#   'aangaan',
#   'aangaande',
#   'aangaat',
#   'aangebied',
#   'aangeblaas',
#   'aangebore',
#   'aangeboren',
#   'aangedaan',
#   'aangedik',
#   'aangedring',
#   'aangedroom',
#   'aangedui',
#   'aangeer',
#   'aangegee',
#   'aangegooi',
#   'aangegryp',
#   'aangehaal',
#   'aangehaalde',
#   'aangehits',
#   'aangeklede',
#   'aangeklop',
#   'aangekomen',
#   'aangekondig',
#   'aangekweek',
#   'aangele',
#   'aangeleerde',
#   'aangeleg',
#   'aangelegde',
#   'aangelok',
#   'aangematigde',
#   'aangemoedig',
#   'aangename',
#   'aangenamer',
#   'aangeneem',
#   'aangenome',
#   'aangeraak',
#   'aangery',
#   'aangesien',
#   'aangesig',
#   'aangesigte',
#   'aangeskrywe',
#   'aangesluit',
#   'aangespoel',
#   'aangespoor',
#   'aangestap',
#   'aangestel',
#   'aangestoom',
#   'aangestrande',
#   'aangeteken',
#   'aangetoon',
#   'aangetoond',
#   'aangetref',
#   'aangevang',
#   'aangevoer',
#   'aangevul',
#   'aangewaai',
#   'aangewaaide',
#   'aangewend',
#   'aangewezen',
#   'aangrensende',
#   'aangryp',
#   'aangrypende',
#   'aanhaling',
#   'aanhalings',
#   'aanhangsel',
#   'aanhangsels',
#   'aanhits',
#   'aanhoor',
#   'aanhou',
#   'aanhoudend',
#   'aanhoudende',
#   'aanklag',
#   'aanklagte',
#   'aanklop',
#   'aanknopingspunt',
#   'aanknopingspunte',
#   'aankom',
#   'aankomende',
#   'aankoms',
#   'aankondiginge',
#   'aankweek',
#   'aanleerden',
#   'aanleg',
#   'aanleiding',
#   'aanlopie',
#   'aanmatig',
#   'aanmekaar',
#   'aanmerking',
#   'aanmerklik',
#   'aanmoediging',
#   'aanneem',
#   'aanpak',
#   'aanprysinge',
#   'aanraai',
#   'aanraking',
#   'aanschouwen',
#   'aanse',
#   'aansien',
#   'aansit',
#   'aanskaf',
#   'aanskou',
#   'aanskouer',
#   'aanskoulike',
#   'aanskoulikheid',
#   'aanslaan',
#   'aanspoor',
#   'aansporing',
#   'aanspraak',
#   'aanspreeklik',
#   'aanstaande',
#   'aanstellerige',
#   'aanstellerij',
#   'aanstip',
#   'aanstormende',
#   'aanstorming',
#   'aanstort',
#   'aanstryk',
#   'aansuis',
#   'aansukkel',
#   'aanswellende',
#   'aansyn',
#   'aantal',
#   'aanteel',
#   'aanteken',
#   'aantekeninge',
#   'aantog',
#   'aantoon',
#   'aantoont',
#   'aantref',
#   'aantrek',
#   'aantreklike',
#   'aantreklikheid',
#   'aanvaar',
#   'aanvaard',
#   'aanvaarding',
#   'aanval',
#   'aanvalle',
#   'aanvang',
#   'aanvanklik',
#   'aanvoel',
#   'aanvoeling',
#   'aanvoelings',
#   'aanvoelingsgawe',
#   'aanvoer',
#   'aanvoerders',
#   'aanvul',
#   'aanwaaisels',
#   'aanwendbaar',
#   'aanwending',
#   'aanwesig',
#   'aanwesigheid',
#   'aanwysings',
#   'aap',
#   'aard',
#   'aardbodem',
#   'aardbol',
#   'aarde',
#   'aardige',
#   'aardigheidjie',
#   'aardrykskunde',
#   'aards',
#   'aardse',
#   'aarsel',
#   'aarseling',
#   'aartsknoeier',
#   'aasvoel',
#   'abbot',
#   'abdol',
#   'aberdeen',
#   'aberdeense',
#   'about',
#   'abram',
#   'abruptly',
#   'absolute',
#   'absoluut',
#   'absorb',
#   'absorption',
#   'abstrakte',
#   'absurd',
#   'absurdity',
#   'abuislike',
#   'account',
#   'achieved',
#   'achievements',
#   'acht',
#   'achter',
#   'achtergrond',
#   'achtte',
#   'acket',
#   'acquaintance',
#   'acted',
#   'acteur',
#   'action',
#   'actions',
#   'actual',
#   'adam',
#   'adama',
#   'adamskind',
#   'added',
#   'addison',
#   'adel',
#   'adelkringe',
#   'adem',
#   'aderen',
#   'adertjes',
#   'adherents',
#   'adhesie',
#   'adjektiewe',
#   'admiraal',
#   'admirable',
#   'adonis',
#   'adres',
#   'adriaan',
#   'adult',
#   'adv',
#   'advies',
#   'advokaat',
#   'advokate',
#   'aen',
#   'aesopus',
#   'aesthetic',
#   'aesthetische',
#   'afbeeld',
#   'afbeelding',
#   'afbeeldsel',
#   'afbreek',
#   'afbrekende',
#   'afbrekery',
#   'afbreuk',
#   'afd',
#   'afdeling',
#   'afdelings',
#   'afdelingsraad',
#   'afdoende',
#   'afdraai',
#   'afdraand',
#   'afdrifsels',
#   'afdruk',
#   'afdryf',
#   'afdwaal',
#   'afdwing',
#   'affairs',
#   'afferes',
#   'affiliasie',
#   'affiniteit',
#   'afford',
#   'afgaan',
#   'afgaande',
#   'afgebakende',
#   'afgebeulde',
#   'afgebrande',
#   'afgebreek',
#   'afgebyt',
#   'afgedruk',
#   'afgegooi',
#   'afgehang',
#   'afgejakkerde',
#   'afgekeur',
#   'afgekoude',
#   'afgekyk',
#   'afgele',
#   'afgelee',
#   'afgeleefde',
#   'afgeleefdheid',
#   'afgeleg',
#   'afgelei',
#   'afgeloop',
#   'afgelope',
#   'afgemaak',
#   'afgemete',
#   'afgeneem',
#   'afgeperk',
#   'afgerinkink',
#   'afgerittel',
#   'afgeronde',
#   'afgeruk',
#   'afgesaagde',
#   'afgesien',
#   'afgeskeer',
#   'afgeskiet',
#   'afgeskilder',
#   'afgeslyte',
#   'afgesny',
#   'afgespeel',
#   'afgespieel',
#   'afgetree',
#   'afgetrek',
#   'afgevrete',
#   'afgeweet',
#   'afgewissel',
#   'afgewys',
#   'afgodedienaar',
#   'afgrond',
#   'afgronde',
#   'afgryslike',
#   'afguns',
#   'afhaal',
#   'afhang',
#   'afhanklik',
#   'afhanklike',
#   'afhanklikheid',
#   'afkeer',
#   'afkerig',
#   'afklim',
#   'afknyp',
#   'afkom',
#   'afkoms',
#   'afkomstig',
#   'afkorting',
#   'afkyk',
#   'afl',
#   'afle',
#   'aflegging',
#   'aflei',
#   'afleweringe',
#   'afluister',
#   'afoes',
#   'aforismes',
#   'afr',
#   'afreis',
#   'african',
#   'africana',
#   'afrika',
#   'afrikaans',
#   'afrikaansch',
#   'afrikaansche',
#   'afrikaanse',
#   'afrikaner',
#   'afrikanerdom',
#   'afrikanerkarakter',
#   'afrikanerpennen',
#   'afrikanerpioniers',
#   'afrikaners',
#   'afrikanervolk',
#   'afsaal',
#   'afscheiding',
#   'afsien',
#   'afskeid',
#   'afskeidsbrief',
#   'afskeidskyk',
#   'afskietery',
#   'afskrikwekkende',
#   'afskryf',
#   'afslaer',
#   'afslag',
#   'afsny',
#   'afsondering',
#   'afsonderlik',
#   'afsonderlike',
#   'afspat',
#   'afspieeling',
#   'afstammeling',
#   'afstand',
#   'afstande',
#   'afstuit',
#   'after',
#   'aftree',
#   'aftrek',
#   'aftreksel',
#   'afweer',
#   'afweet',
#   'afwering',
#   'afwerk',
#   'afwikkeling',
#   'afwisselende',
#   'afwisseling',
#   'afwyk',
#   'afwykinge',
#   'afwykte',
#   'again',
#   'age',
#   'agent',
#   'agentskantoortjie',
#   'agste',
#   'agteloos',
#   'agter',
#   'agterbly',
#   'agterblywende',
#   'agterbuurte',
#   'agterdeel',
#   'agterdog',
#   'agtergrond',
#   'agterlatend',
#   'agterlik',
#   'agterlike',
#   'agterlikes',
#   'agtermekaar',
#   'agterna',
#   'agternatrekkers',
#   'agterrede',
#   'agterryer',
#   'agterste',
#   'agterstevoor',
#   'agterstevoortrekkers',
#   'agtertoe',
#   'agteruit',
#   'agteruitbeur',
#   'agteruitgang',
#   'agterveldse',
#   'agtervolg',
#   'agterwaarts',
#   'agterwee',
#   'agterwege',
#   'agtien',
#   'agtiende',
#   'agtige',
#   'agting',
#   'aias',
#   'aires',
#   'akademie',
#   'akademies',
#   'akademiese',
#   'akker',
#   'akkerbome',
#   'akkoorde',
#   'akkuraat',
#   'akrobatiek',
#   'aksent',
#   'aksie',
#   'aktief',
#   'aktiewe',
#   'aktueel',
#   'aktuele',
#   'albei',
#   'albert',
#   'album',
#   'aldaagse',
#   'aldag',
#   'aldeur',
#   'aldus',
#   'alfred',
#   'algar',
#   'algemeen',
#   'algemeene',
#   'algemeenheid',
#   'algemene',
#   'algeval',
#   'alheersend',
#   'alhier',
#   'alhoewel',
#   'aliis',
#   'all',
#   'alla',
#   'allan',
#   'allard',
#   'alle',
#   'alledaags',
#   'alledaagsch',
#   'alledaagsche',
#   'alledaagse',
#   'alleen',
#   'alleenstaande',
#   'allegaartjie',
#   'allegorie',
#   'allen',
#   'allenigheid',
#   'aller',
#   'allerbeste',
#   'allereers',
#   'allereerste',
#   'allergewoonste',
#   'allerhande',
#   'allerhoogste',
#   'allerkoddigste',
#   'allerlaaste',
#   'allerlei',
#   'allerley',
#   'allerliefs',
#   'allermins',
#   'allernederigste',
#   'allerpragtigste',
#   'allerskoonste',
#   'allersnaakste',
#   'alleryl',
#   'alles',
#   'allesbehalwe',
#   'allesbeheersende',
#   'allesins',
#   'allesoorwinnende',
#   'alliterasie',
#   'allitereer',
#   'allures',
#   'almaal',
#   'almag',
#   'almagtige',
#   'almal',
#   'almanak',
#   'almelewe',
#   'almiskie',
#   'alom',
#   'alomkennis',
#   'along',
#   'aloof',
#   'aloud',
#   'alpenveld',
#   'alphen',
#   'alreeds',
#   'als',
#   'alsnog',
#   'also',
#   'alsof',
#   'altaar',
#   'altans',
#   'alte',
#   'altemit',
#   'alternatief',
#   'altijd',
#   'altoos',
#   'altruisme',
#   'altwee',
#   'altyd',
#   'altydlopende',
#   'alvorens',
#   'alwaar',
#   'always',
#   'alweer',
#   'amalie',
#   'ambagsman',
#   'ambagt',
#   'ambagte',
#   'ambiesie',
#   'ambiguity',
#   'ambisie',
#   'ambt',
#   'ambulans',
#   'ambulanstreine',
#   'ame',
#   'amerika',
#   'amerikaanse',
#   'amerikaner',
#   'ammuniesie',
#   'among',
#   'amper',
#   'ampie',
#   'ample',
#   'amptenaar',
#   'amptenare',
#   'amsterdam',
#   'amsterdamse',
#   'amusements',
#   'amusementsroman',
#   'anakronistiese',
#   'analiese',
#   'analiseer',
#   'analoge',
#   'and',
#   'ander',
#   'andere',
#   'anderen',
#   'anderkant',
#   'anderkantse',
#   'anders',
#   'andersins',
#   'andries',
#   'anekdote',
#   'anekdotes',
#   'angel',
#   'angelo',
#   'anglaise',
#   'anglisisme',
#   'anglisismes',
#   'anglo',
#   'angs',
#   'angstig',
#   'angsvallig',
#   'angsvalligheid',
#   'anguish',
#   'animal',
#   'animositeit',
#   'ankertjie',
#   'anna',
#   'anne',
#   'anneksasie',
#   'annette',
#   'annie',
#   'antagonists',
#   'anthonie',
#   'anti',
#   'antjie',
#   'anton',
#   'antoon',
#   'antwerpen',
#   'antwoord',
#   'antwoordende',
#   'any',
#   'anybody',
#   'anything',
#   'apart',
#   'aparte',
#   'ape',
#   'apery',
#   'aploon',
#   'apologie',
#   'apparaat',
#   'appeal',
#   'appear',
#   'appel',
#   'appelkoos',
#   'appels',
#   'appresiasie',
#   'april',
#   'aprilmaand',
#   'arbeid',
#   'arbez',
#   'architect',
#   'are',
#   'aretes',
#   'argaistiese',
#   'argelose',
#   'argentinie',
#   'argeologiese',
#   'argeoloog',
#   'argief',
#   'argieflug',
#   'argiefondersoek',
#   'argiewe',
#   'argitektuur',
#   'argument',
#   'argumente',
#   'argwaan',
#   'aristocratic',
#   'aristokrate',
#   'arm',
#   'arme',
#   'armen',
#   'armes',
#   'armoede',
#   'armoedige',
#   'armoedigste',
#   'arms',
#   'armsalige',
#   'armswaai',
#   'arnoldus',
#   'arriveer',
#   'art',
#   'artiekel',
#   'artiekels',
#   'artiekeltjie',
#   'arties',
#   'artiest',
#   'artieste',
#   'artiesten',
#   'artifisiele',
#   'artist',
#   'artistic',
#   'artistiek',
#   'artistieke',
#   'aschenborn',
#   'asem',
#   'asemloos',
#   'asgaai',
#   'asleep',
#   'asnog',
#   'asof',
#   'asook',
#   'aspects',
#   'aspirant',
#   'aspirasie',
#   'aspirasies',
#   'asplekke',
#   'asseblief',
#   'assemble',
#   'assenburgh',
#   'assessed',
#   'assistent',
#   'assuredly',
#   'astrant',
#   'astrante',
#   'astronomiese',
#   'atmosfeer',
#   'atmosferiese',
#   'atmospheric',
#   'atoom',
#   'attachment',
#   'auf',
#   'aug',
#   'august',
#   'augustus',
#   'aula',
#   'auntie',
#   'australie',
#   'auteur',
#   'author',
#   'autres',
#   'avenir',
#   'average',
#   'avonturen',
#   'awendstond',
#   'awful',
#   'awonture',
#   'awonturereeks',
#   'awontuur',
#   'awontuurlike',
#   'awontuurlikheid',
#   'awontuurtjies',
#   'baadjie',
#   'baai',
#   'baaiende',
#   'baaiery',
#   'baaisikkel',
#   'baan',
#   'baanbreker',
#   'baanbrekers',
#   'baard',
#   'baarlike',
#   'baas',
#   'baat',
#   'babbelende',
#   'babbelpraat',
#   'babetjies',
#   'back',
#   'backhaus',
#   'bad',
#   'badende',
#   'badkamer',
#   'baffled',
#   'baie',
#   'baik',
#   'bak',
#   'bakbene',
#   'baken',
#   'baker',
#   'bakkerskloof',
#   'bakkies',
#   'baklei',
#   'bakoond',
#   'baksteen',
#   'bal',
#   'balken',
#   'balling',
#   'baloorig',
#   'balsem',
#   'banaal',
#   'banaalste',
#   'banale',
#   'banaliteite',
#   'band',
#   'bande',
#   'bandeliers',
#   'bandelose',
#   'bang',
#   'bange',
#   'bangerige',
#   'bangste',
#   'bank',
#   'banked',
#   'banvloek',
#   'barbaar',
#   'barbaarse',
#   'barbare',
#   'barbarisme',
#   'bargain',
#   'barolongs',
#   'bars',
#   'bas',
#   'basaar',
#   'basmusiek',
#   'basoeto',
#   'basoetoeland',
#   'basoetoland',
#   'basson',
#   'basstem',
#   'basterdelemente',
#   'bastiaanse',
#   'batavia',
#   'battery',
#   'battle',
#   'battles',
#   'baumann',
#   'bazen',
#   'beauty',
#   'bebliek',
#   'because',
#   'bed',
#   'bedaar',
#   'bedaarde',
#   'bedagsaamheid',
#   'bedagte',
#   'bedank',
#   'bedeel',
#   'bedeeld',
#   'bedek',
#   'bedekte',
#   'bedelaars',
#   'bedeling',
#   'bedenk',
#   'bedenkend',
#   'bedenking',
#   'bedenkings',
#   'bedenklik',
#   'bedenklike',
#   'bedenksel',
#   'bederf',
#   'bederwe',
#   'bedien',
#   'bedleerige',
#   'bedoel',
#   'bedoeling',
#   'bedoelinge',
#   'bedoelings',
#   'bedolwe',
#   'bedompige',
#   'bedreig',
#   'bedrieer',
#   'bedriegelik',
#   'bedriegster',
#   'bedrijf',
#   'bedrog',
#   'bedrogen',
#   'bedryf',
#   'bedrywe',
#   'bedrywige',
#   'bedrywigheid',
#   'bedui',
#   'beduie',
#   'bedwelmende',
#   'bedwing',
#   'beeindig',
#   'beeld',
#   'beelde',
#   'beelden',
#   'beeldende',
#   'beeldhouer',
#   'beeldhoukuns',
#   'beeldhouwerk',
#   'beelding',
#   'beeldspraak',
#   'beelzebub',
#   'been',
#   'beendere',
#   'beenderige',
#   'beentjies',
#   'beer',
#   'beesagtige',
#   'beeste',
#   'beet',
#   'beethoven',
#   'beetje',
#   'beetkry',
#   'beetrye',
#   'beets',
#   'begaafde',
#   'begaan',
#   'begeef',
#   'begeerte',
#   'begeertes',
#   'begeestering',
#   'begenadigde',
#   'begenadigdes',
#   'begewe',
#   'begin',
#   'beginne',
#   'beginner',
#   'beginsel',
#   'beginsels',
#   'begint',
#   'beglans',
#   'begleitet',
#   'begocheld',
#   'begonnen',
#   'begrafnis',
#   'begrawe',
#   'begrepen',
#   'begrijpt',
#   'begrip',
#   'begrippe',
#   'begrippen',
#   'begroet',
#   'begryp',
#   'begrypende',
#   'begryplik',
#   'begun',
#   'behaag',
#   'behaal',
#   'behae',
#   'behagen',
#   'behalwe',
#   'behandel',
#   'behandelde',
#   'behandeling',
#   'behartig',
#   'behaviour',
#   'beheers',
#   'behelp',
#   'behendig',
#   'behendigheid',
#   'behoef',
#   'behoefte',
#   'behoeftes',
#   'behoor',
#   'behoorlik',
#   'behoort',
#   'behou',
#   'behoud',
#   'behulp',
#   'bei',
#   'beide',
#   'being',
#   'beinvloed',
#   'bejaarde',
#   'bejammerd',
#   'bek',
#   'bekeer',
#   'bekeerd',
#   'bekeeren',
#   'bekeering',
#   'bekend',
#   'bekende',
#   'bekendstel',
#   'beker',
#   'bekering',
#   'bekkie',
#   'beklagenswaardige',
#   'beklee',
#   'beklemde',
#   'beklemmende',
#   'beknop',
#   'beknopte',
#   'bekoeling',
#   'bekommer',
#   'bekommerde',
#   'bekoor',
#   'bekoorlike',
#   'bekoorliker',
#   'bekoorlikheid',
#   'bekoring',
#   'bekostig',
#   'bekrompenheid',
#   'bekroon',
#   'bekroonde',
#   'bekruip',
#   'bekwaam',
#   'bekwaamhede',
#   'bekwaamheid',
#   'bekwame',
#   'bekyk',
#   'belaai',
#   'belang',
#   'belange',
#   'belangrik',
#   'belangrike',
#   'belangrikheid',
#   'belangriks',
#   'belangrikste',
#   'belangstellende',
#   'belangstelling',
#   'belangwekkende',
#   'belastingkwellings',
#   'beleef',
#   'beleefd',
#   'beleefde',
#   'beleefdheidsfrases',
#   'beleeft',
#   'belegering',
#   'belemmer',
#   'belemmerd',
#   'belemmerende',
#   'belet',
#   'belewe',
#   'belichting',
#   'belief',
#   'belig',
#   'belletristiese',
#   ...],
#  'arapaho': ['aarauneau',
#   'abel',
#   'abia',
#   'abilene',
#   'abraham',
#   'abrahamvene',
#   'according',
#   'across',
#   'adam',
#   'addi',
#   'ahagu',
#   'all',
#   'almost',
#   'alone',
#   'always',
#   'american',
#   'aminadab',
#   'amos',
#   'and',
#   'andwheau',
#   'anna',
#   'annas',
#   'any',
#   'appear',
#   'appearances',
#   'appears',
#   'aram',
#   'are',
#   'arimathaea',
#   'arphaxad',
#   'aser',
#   'atheas',
#   'augustus',
#   'auhanau',
#   'barabbas',
#   'bathaunaumew',
#   'bau',
#   'beelzebub',
#   'beelzehub',
#   'been',
#   'being',
#   'bethany',
#   'bethlehem',
#   'bethphage',
#   'bethsaida',
#   'bible',
#   'biblical',
#   'book',
#   'booz',
#   'both',
#   'but',
#   'caesar',
#   'caiaphas',
#   'cainan',
#   'calvary',
#   'camel',
#   'capernaum',
#   'capitalized',
#   'certainly',
#   'chauayau',
#   'chauayaunau',
#   'chauchaunu',
#   'chaunauguauau',
#   'chaunauguuthadee',
#   'chaunaunauaunith',
#   'chaunuvade',
#   'chaunuwuthajaudaunaude',
#   'chorazin',
#   'chosen',
#   'chris',
#   'chrisdenagu',
#   'chrisdeyaugu',
#   'chuvahagu',
#   'chuwauthee',
#   'chuwuu',
#   'chuza',
#   'chwuwuu',
#   'cleopas',
#   'closer',
#   'coincides',
#   'colon',
#   'common',
#   'cosam',
#   'could',
#   'cyrenene',
#   'cyrenius',
#   'daayae',
#   'dachauauwuu',
#   'dachaugu',
#   'dadajevenau',
#   'dadajevenenaje',
#   'dadajevenevesaa',
#   'dadajevenevese',
#   'dadajevenevesenethauchayau',
#   'dadajevenevesenethauchayaunaa',
#   'dadaunaugagaunee',
#   'dadaunauguu',
#   'dadaunedan',
#   'dadaunee',
#   'dadauyauha',
#   'dadavechaudenenee',
#   'dade',
#   'daedauwunathana',
#   'daesathae',
#   'daeyaunaa',
#   'daeyaunauau',
#   'daeyaunauauau',
#   'daeyaunenede',
#   'dajaee',
#   'dajanau',
#   'dajanaunaa',
#   'dajanaune',
#   'dajauaunee',
#   'dajechauau',
#   'dajee',
#   'dajenehede',
#   'danaahethe',
#   'danachaugunethe',
#   'danadauyauau',
#   'danadethadethee',
#   'dasauhaudauau',
#   'dasee',
#   'dasejaneseagu',
#   'dasenaunanaunee',
#   'dasewauthaunauha',
#   'dathajee',
#   'datheveehauchavesau',
#   'datheveehauchavesaun',
#   'datheveehauchavesaune',
#   'dau',
#   'dauaenaunauthee',
#   'dauanadethee',
#   'dauanaude',
#   'dauauachaudenee',
#   'dauaudauwuthajaude',
#   'dauaugauhude',
#   'dauaugauthethajauduu',
#   'dauaunauthedade',
#   'dauauthedaunade',
#   'dauauthedaunenede',
#   'dauauthesenenee',
#   'dauchuuwuse',
#   'dauchuuwusee',
#   'dauchuvahethee',
#   'daudajauaunenethaunena',
#   'daudaneaauna',
#   'daudauna',
#   'daudaus',
#   'daudause',
#   'daudausee',
#   'daude',
#   'daudu',
#   'dauethunevethehedaunee',
#   'daugaudauwuthajauthee',
#   'daugaugaunauauwunanenenau',
#   'daugaugaunauauwunanenene',
#   'daugauha',
#   'daugauhauwune',
#   'dauguthetheaugude',
#   'dauhadavesane',
#   'dauhaenauau',
#   'dauhaenauwunethe',
#   'dauhaenuu',
#   'dauhaeyanith',
#   'dauhanadede',
#   'dauhanadene',
#   'dauhanajauwauaunauthee',
#   'dauhasauhauvade',
#   'dauhayanajaa',
#   'dauhenayauhane',
#   'dauhuanadede',
#   'dauhuauchauau',
#   'dauhuaudaa',
#   'dauhuawaude',
#   'dauhudanauwuna',
#   'dauhudauchanau',
#   'dauhudauchu',
#   'dauhujaathehade',
#   'dauhujenethaunanauau',
#   'dauhunaasedaude',
#   'dauhunauchuwuhunene',
#   'dauhunauhaudauwuna',
#   'dauhunedaehawaude',
#   'dauhunedauwaude',
#   'dauhusathane',
#   'dauhusedanade',
#   'dauhuthenane',
#   'dauhuwauthanedauwauthaude',
#   'daujaahede',
#   'daujadade',
#   'daujaenaedeyaugaune',
#   'daujaenaunene',
#   'daujaenauwu',
#   'daujaenuu',
#   'daujaesedanaude',
#   'daujaethauwauthede',
#   'daujaeveenauwau',
#   'daujaheseuhunith',
#   'daujajaathehade',
#   'daujajawauaunadena',
#   'daujanaugudaunaude',
#   'daujanaugude',
#   'daujanaugunith',
#   'daujasesenauauau',
#   'daujauaudaunaudauau',
#   'daujaveehauau',
#   'daujavesade',
#   'daujeanauau',
#   'daujechuwauthenaedene',
#   'daujedade',
#   'daujedathee',
#   'daujeeseaunau',
#   'daujenajenee',
#   'daujenaudedenau',
#   'daujenauhauwaude',
#   'daujenauthanau',
#   'daujeneaunaudaunanaune',
#   'daujeneauthedaunauthee',
#   'daujeneethajauduu',
#   'daujethauwaudauwu',
#   'daujewaunejaathededaunee',
#   'daujeyauthesee',
#   'daun',
#   'daunaadade',
#   'daunaaudaa',
#   'daunaene',
#   'daunahagu',
#   'daunajanethe',
#   'daunanenau',
#   'daunathajauthee',
#   'daunathaunee',
#   'daunauanaduu',
#   'daunauanauthee',
#   'daunauauvasee',
#   'daunaudehauthee',
#   'daunauganenee',
#   'daunauhaudauwunethe',
#   'daunauhauduu',
#   'daunauhauthade',
#   'daunauhauthethade',
#   'daunaunauhauthethade',
#   'daunaunenechuhunith',
#   'daunausujaude',
#   'daunausujavesathee',
#   'daunausunanadede',
#   'daunausunanadethee',
#   'daunausunaugunauthee',
#   'daunausuvadanedaude',
#   'daunausuvevethahede',
#   'daunausuvevethauchaude',
#   'daunausuyehaude',
#   'daunausuyehauthee',
#   'daunauthetheaugunethe',
#   'daunauthethenadedaunenee',
#   'daunauujadaunanau',
#   'daunauusade',
#   'daunechaudaa',
#   'daunedaunathane',
#   'daunedauvade',
#   'daunedauwaudauwunith',
#   'dauneenahede',
#   'dauneethenadedaunenee',
#   'daunenehedauau',
#   'daunesenesethanau',
#   'daunethauyadauchudede',
#   'daunevade',
#   'daunhadahenith',
#   'daunhaene',
#   'daunhasenehede',
#   'daunhathahenith',
#   'daunhayewhu',
#   'daunjanenethenaude',
#   'daunjaunaude',
#   'daunudesanaunee',
#   'daununanau',
#   'daununauthee',
#   'dauthedaunaanehadaugauchaudee',
#   'dauuchauwauaunauna',
#   'dauudasadee',
#   'dauudasathane',
#   'dauunayauhade',
#   'dauusahede',
#   'dauusenadenau',
#   'dauuyaudahethee',
#   'dauvadavehahenede',
#   'dauvanaa',
#   'dauvaveenethedaunaude',
#   'dauvechauthade',
#   'dauveeyauau',
#   'dauvethede',
#   'dauvethehethee',
#   'dauvevethahede',
#   'dauwauhune',
#   'dauwauthaa',
#   'dauwauthanee',
#   'dauwauthaunauhuu',
#   'dauyanusenade',
#   'dauyaudaunaude',
#   'dauyethaasade',
#   'dauyewuwuthedaune',
#   'dauyewuwuu',
#   'dauyuuwuu',
#   'davadeesehee',
#   'davathejajaneauthee',
#   'david',
#   'dayanauauchauau',
#   'deadethade',
#   'deanadethanauau',
#   'deanedaude',
#   'deasenade',
#   'deathavejenanathana',
#   'deauchuwunanenede',
#   'deausaguthaugaunee',
#   'dechauchuwuhadethee',
#   'dechauhauthethade',
#   'decided',
#   'deduguhude',
#   'deejethasee',
#   'deejevanaa',
#   'deenaedede',
#   'deenaedene',
#   'deethauwunethauya',
#   'degaujauaudade',
#   'degaujauaudahenith',
#   'deguthevevethahethee',
#   'deheauthedaunee',
#   'dehedusaananau',
#   'dejachauthana',
#   'dejanesee',
#   'dejanethajaudauwu',
#   'dejauaunee',
#   'dejauthauwuvade',
#   'dejedade',
#   'dejeesedaude',
#   'dejegauausauhathee',
#   'dejejenayathee',
#   'dejenanauwunauthee',
#   'dejenanuu',
#   'dejenauhauwuu',
#   'dejenauhunee',
#   'dejenauhuu',
#   'dejeveedethee',
#   'dejevethee',
#   'dejewaunejaathehaude',
#   'deliberate',
#   'denaade',
#   'denajaa',
#   'denanadesanauau',
#   'denauachauau',
#   'denauaunenaugauyanethe',
#   'denauauthee',
#   'denaudedede',
#   'denauhauthehade',
#   'denauhauthethathee',
#   'denaunaunauchauthehanau',
#   'denaunethauaude',
#   'denausunanedaude',
#   'denausunaugauhuu',
#   'denausunauthedade',
#   'denausunethenaedevathana',
#   'denauusade',
#   'denayauthanith',
#   'deneauwauhude',
#   'denede',
#   'denehena',
#   'denesedaunauna',
#   'denesenenee',
#   'denethenaedevathana',
#   'desene',
#   'desenee',
#   'desenenee',
#   'deseuujenayaunau',
#   'dethauwunauauau',
#   'devadaunauhauwaude',
#   'devadaunedauwauduu',
#   'devahenesaunadae',
#   'devanauhauna',
#   'devasauau',
#   'devechaudauwuna',
#   'devechauthade',
#   'devenanau',
#   'devevethahede',
#   'devevethahethee',
#   'dewauchahenethe',
#   'dewauthanethe',
#   'deyehaunauau',
#   'differences',
#   'direct',
#   'does',
#   'doesn',
#   'duguhunauauwuu',
#   'duguthahe',
#   'duguthahew',
#   'duguthanauauwuu',
#   'dunauaugu',
#   'dusaahede',
#   'dusaaya',
#   'dusaayahe',
#   'dusaayahew',
#   'dusau',
#   'dusaudee',
#   'dusaune',
#   'dusedaudene',
#   'dusee',
#   'dusewauchudau',
#   'duthaee',
#   'duthaenanauthaune',
#   'duthanau',
#   'duthanee',
#   'duujehe',
#   'duujehee',
#   'earlier',
#   'either',
#   'eleven',
#   'eliakim',
#   'elias',
#   'eliaseau',
#   'eliezer',
#   'elisabeth',
#   'eliseus',
#   'elmodam',
#   'else',
#   'elsewhere',
#   'emmaus',
#   'enoch',
#   'enos',
#   'errors',
#   'esaias',
#   'esli',
#   'esrom',
#   'except',
#   'find',
#   'follow',
#   'for',
#   'foreign',
#   'former',
#   'gabriel',
#   'gadarenes',
#   'gananaean',
#   'gananane',
#   'ganane',
#   'gananeans',
#   'gananee',
#   'gauanee',
#   'gauauwuauau',
#   'gauchauaa',
#   'gauchauchaunu',
#   'gauchuhuchaudede',
#   'gauchuhunee',
#   'gauchujade',
#   'gauchujanith',
#   'gaudauyauhunauau',
#   'gauduaunanauau',
#   'gaugauanadauwuu',
#   'gaugauanavaa',
#   'gaugauchu',
#   'gaugauguyase',
#   'gaugauthau',
#   'gaugauuthajaudenau',
#   'gaugauyaune',
#   'gauha',
#   'gauhaavedaudauna',
#   'gauhade',
#   'gauhadjedauauwaunauau',
#   'gauhadjedeauchauau',
#   'gauhadjejanaugu',
#   'gauhadnanene',
#   'gauhadnaudeha',
#   'gauhadnaudenauhauwau',
#   'gauhadnautha',
#   'gauhadnauuguthauva',
#   'gauhadneenedanau',
#   'gauhadnenayauha',
#   'gauhadvaveene',
#   'gauhadvavesenaudene',
#   'gauhadveede',
#   'gauhadvena',
#   'gauhadvenaa',
#   'gauhadwaudeau',
#   'gauhae',
#   'gauhaejau',
#   'gauhaejauva',
#   'gauhaeyahe',
#   'gauhajaene',
#   'gauhajavaaneenaedeva',
#   'gauhajeadaunau',
#   'gauhajegaudauvanade',
#   'gauhajene',
#   'gauhajeneenesehauva',
#   'gauhajethaunauhaude',
#   'gauhajeva',
#   'gauhajevathehava',
#   'gauhajevetheneva',
#   'gauhanadethaa',
#   'gauhanane',
#   'gauhanauha',
#   'gauhauaugunaugauye',
#   'gauhauchae',
#   'gauhauchagu',
#   'gauhauchanauha',
#   'gauhaudjenesauujanesenauau',
#   'gauhaudnauthedaunathava',
#   'gauhaujau',
#   'gauhaunaude',
#   'gauhaunauhauwau',
#   'gauhenane',
#   'gauhuhuthaune',
#   'gauhujavaanauhauganenauau',
#   'gauhujavaneauthau',
#   'gaujauaudahedaunaa',
#   'gaujauaudahede',
#   'gaujauaudahehe',
#   'gaujauaudahehehau',
#   'gaujauaudahehehauau',
#   'gaujauaudahenauau',
#   'gaujauaudahenauauwu',
#   'gaujauaudaheyaugaune',
#   'gaujee',
#   'gaujenaasaunee',
#   'gaujenanavanau',
#   'gaujenane',
#   'gaujenayauhaunauau',
#   'gaujevadaunedauwaune',
#   'gaujewauthanauau',
#   'gaunaasauau',
#   'gaunanenauguhu',
#   'gaunauanuu',
#   'gaunaudauauha',
#   'gaunauwuu',
#   'gauneee',
#   'gauneevaejetha',
#   'gaunudanauwunade',
#   'gaunudanauwunana',
#   'gaunudanauwunane',
#   'gaunuu',
#   'gauthanenevajaunaa',
#   'gauthanevasevenenaje',
#   'gauthayauau',
#   'gauthayaunee',
#   'gauuhanaa',
#   'gauusevanenagu',
#   'gauuu',
#   'gauwauathe',
#   'gauwuhaude',
#   'gauwuhaudeneagu',
#   'gayethaajethauva',
#   'generally',
#   'gennesaret',
#   'giving',
#   'gospel',
#   'grammatical',
#   'greek',
#   'gudanadede',
#   'gujeaudaunaune',
#   'haa',
#   'haadahevadenau',
#   'haadenenayautha',
#   'haadeneseenethe',
#   'haadethaude',
#   'haaedauwunadaunene',
#   'haaenaudede',
#   'haaenaunaude',
#   'haaenauwunith',
#   'haaenuu',
#   'haahenau',
#   'haajevesehau',
#   'haanaaenauauchauau',
#   'haanauusade',
#   'haanauusanaune',
#   'haanedaude',
#   'haanedauthe',
#   'haathanaveva',
#   'haathauwuavaa',
#   'haau',
#   'haauauvadenee',
#   'haauchauau',
#   'haauchaunee',
#   'haauchuwudede',
#   'haaugunade',
#   'haaugunauna',
#   'haauthedaunathadenenau',
#   'haauwaudauaunethe',
#   'haayaedadauau',
#   'haayajenauusanith',
#   'haayanaesade',
#   'haayanauusade',
#   'hachaunaa',
#   'hachaunau',
#   'hachaunenau',
#   'hachauwunagu',
#   'hadaahedaunaa',
#   'hadadaunahedaunaa',
#   'hadadaunahedaunenau',
#   'hadade',
#   'hadadethaunauau',
#   'hadaedauwunathava',
#   'hadaedauwunaude',
#   'hadaedauwunauva',
#   'hadaehahenau',
#   'hadaehauhauau',
#   'hadaenathaunenau',
#   'hadaenauwu',
#   'hadaenava',
#   'hadaeyaunevenau',
#   'hadaeyaunewauau',
#   'hadahaa',
#   'hadahena',
#   'hadahenau',
#   'hadahenauau',
#   'hadahene',
#   'hadahethedaunadaunenau',
#   'hadahethee',
#   'hadahevahe',
#   'hadahevahew',
#   'hadahewaude',
#   'hadahewaunadaune',
#   'hadaje',
#   'hadajee',
#   'hadanadedaunenau',
#   'hadanadede',
#   'hadanadethauva',
#   'hadanayau',
#   'hadanayaunenau',
#   'hadanedauva',
#   'hadanethaude',
#   'hadasea',
#   'hadathuvaa',
#   'hadau',
#   'hadauanauau',
#   'hadauanenau',
#   'hadauchaa',
#   'hadauchae',
#   'hadauchanenee',
#   'hadauchude',
#   'hadauchugauaudayauau',
#   'hadauchunanede',
#   'hadauchunanenethe',
#   'hadauchusenee',
#   'hadauchusenenee',
#   'hadauchuthee',
#   'hadauchuunee',
#   'hadauchuvathehathe',
#   'hadauchuvejanenee',
#   'hadauchuwuhathane',
#   'hadauchuwunanevene',
#   'hadaudadauyaunee',
#   'hadaudaunaudenee',
#   'hadaudavee',
#   'hadaude',
#   'hadaudugauyasaa',
#   'hadauethadee',
#   'hadaugauchauchanee',
#   'hadaugauchaudae',
#   'hadaugaugunesade',
#   'hadaugauhauchanee',
#   'hadaugauhauwunathe',
#   'hadaugauthayaunee',
#   'hadaugautheavadenenau',
#   'hadaugauwudaunaa',
#   'hadaugunauva',
#   'hadauhanadethee',
#   'hadauhauauyauau',
#   'hadaujauudanenee',
#   'hadaujedana',
#   'hadaujenajenenee',
#   'hadaunajavanethe',
#   'hadaunauau',
#   'hadaunaudaunathane',
#   'hadaunaunehau',
#   'hadaunauwuthajau',
#   'hadaunechaudanee',
#   'hadaunee',
#   'hadaunith',
#   'hadausaesee',
#   'hadausaesenanethe',
#   'hadausaesenanith',
#   'hadautheawauau',
#   'hadauthedaunathava',
#   'hadauthee',
#   'hadauunesenenith',
#   'hadauuthadee',
#   'hadauuthadenee',
#   'hadauuyauthaunee',
#   'hadauvasathanethe',
#   'hadauvasathanith',
#   'hadauvasenejesauau',
#   'hadauvathehane',
#   'hadauveeyauau',
#   'hadauveeyaunee',
#   'hadauwausaunee',
#   'hadauwauthaunauhunee',
#   'hadauwauyauau',
#   'hadauwauyaunee',
#   'hadavechaude',
#   'hadavechauthadede',
#   'hadavechauthau',
#   'hadavenuhu',
#   'hadavenuhuhanau',
#   'hadavenuhuhau',
#   'hadavenuhuhauau',
#   'hadavenuhunede',
#   'hadavenuhunena',
#   'hadavenuhunethee',
#   'hadchuvahevathe',
#   'hadchuvanee',
#   'haddadaunaugunith',
#   'haddaudeauau',
#   'haddaugauhudauwuna',
#   'haddauhujesenethauguvathe',
#   'haddaununaude',
#   'haddauthedaude',
#   'haddauwauhude',
#   'haddayahene',
#   'haddenanaunauuu',
#   'haddetheauguna',
#   'haddeyehau',
#   'haddugauyaaunane',
#   'hadduguhude',
#   'haddunanaune',
#   'haddusaahethee',
#   'haddusaanaude',
#   'haddusedaune',
#   'haddusenesau',
#   'haddusevaveeneva',
#   'hadduujede',
#   'hadduunaasau',
#   'hadeaedauwunaude',
#   'hadeaenauwu',
#   'hadeanathaunau',
#   'hadeaudaunava',
#   'hadeaunauwuthajaunauau',
#   'hadedaewaunauau',
#   'hadedanaunenau',
#   'hadedanenau',
#   'hadedanene',
#   'hadedauchuwuwuna',
#   'hadedaunee',
#   'hadedauyauvanauau',
#   'hadeechauchaunaa',
#   'hadeehaudenee',
#   'hadeehaunau',
#   'hadeejedunanaune',
#   'hadeenanedanede',
#   'hadeenayauhana',
#   'hadeesedanana',
#   'hadeesedanauwau',
#   'hadegauchuhuauwuna',
#   'hadegaugauanauwaunauau',
#   'hadegauuchu',
#   'hadegauyaejaheva',
#   'hadeheaenaunee',
#   'hadehedaugu',
#   'hadeheenauguana',
#   'hadejasedauthee',
#   'hadejau',
#   'hadejauaujaunenede',
#   'hadejaude',
#   'hadejedana',
#   'hadejedanauau',
#   'hadejegunauhade',
#   'hadejejedana',
#   'hadejejedathee',
#   'hadejejenanaude',
#   'hadejenadegaudenauau',
#   'hadejenanedaunehana',
#   'hadenaa',
#   'hadenaaeneaugauhauwu',
#   'hadenaaeneauvane',
#   'hadenaasehathane',
#   'hadenaededaunenau',
#   'hadenaededaunene',
#   'hadenahavaewauva',
#   'hadenanedanena',
#   'hadenauaune',
#   'hadenauhaudauau',
#   'hadenauuchaudaunauthee',
#   'hadenayauhauau',
#   'hadenayauhauva',
#   'hadenedahevanau',
#   'hadeneehauthee',
#   'hadeneethajau',
#   'hadeneeyaudanene',
#   'hadenehanahenauau',
#   'hadenesedauna',
#   'hadenethee',
#   'hadesaanudeva',
#   'hadesane',
#   'hadesathee',
#   'hadeseau',
#   'hadeseve',
#   'hadethadaune',
#   'hadethade',
#   'hadethane',
#   'hadethanenagu',
#   'hadethaude',
#   'hadethauguhauva',
#   'hadethauna',
#   'hadethauva',
#   'hadethauwaenava',
#   'hadethauwaudadenenau',
#   'hadethauwaudaude',
#   'hadethauwauthedaunathava',
#   'hadethauwunehesena',
#   'hadethauwuthajaude',
#   'hadethavathe',
#   'hadetheaugudauwuna',
#   'hadeva',
#   'hadevachunauthauyauau',
#   'hadevanava',
#   'hadevaveya',
#   'hadevaveyana',
#   'hadevenau',
#   'hadevenauau',
#   'hadevethehedaunee',
#   'hadevethehena',
#   'hadevethenauau',
#   'hadevetheva',
#   'hadevevethedaunaude',
#   'hadeyehaunau',
#   'hadgauanathee',
#   'hadgauanee',
#   'hadgauchuhuvade',
#   'hadgauduaunana',
#   'hadgauguusenith',
#   'hadgauhanau',
#   'hadgaunanauwunade',
#   'hadgaunauhauau',
#   'hadgauuchauwau',
#   'hadgauusevana',
#   'hadgudanade',
#   'hadgudanauwunanau',
#   'hadgusenauauau',
#   'hadguthauau',
#   'hadjaanauwauva',
#   'hadjaanauwunathane',
#   'hadjaanauwunaunauau',
#   'hadjaanenee',
#   'hadjaasanenee',
#   'hadjaathehade',
#   'hadjaathehanau',
#   'hadjachaudauneva',
#   'hadjadasauaunaunauau',
#   'hadjadaunade',
#   'hadjaechuwauyaauau',
#   'hadjaechuwauyaaunaude',
#   'hadjaedauvanethe',
#   'hadjaedauwunaunethe',
#   'hadjaegauhade',
#   'hadjaegauhasanade',
#   'hadjaegauhathee',
#   'hadjaegauusedaunana',
#   'hadjaegudanauwunade',
#   'hadjaegudanauwunaude',
#   'hadjaegudanauwunauva',
#   'hadjaegudanee',
#   'hadjaejanauhanee',
#   'hadjaejaude',
#   'hadjaenaunauthee',
#   'hadjaenaunee',
#   'hadjaesanau',
#   'hadjajathaauva',
#   'hadjananee',
#   'hadjanaugu',
#   'hadjanauguduu',
#   'hadjanauguhaude',
#   'hadjanesaa',
#   'hadjanesewaude',
#   'hadjathaaude',
#   'hadjathane',
#   'hadjathaunauau',
#   'hadjathauva',
#   'hadjaude',
#   'hadjaunith',
#   'hadjauthee',
#   'hadjavaananethauauyauau',
#   'hadjavaanesedanauau',
#   'hadjavaavasathaa',
#   'hadjavaavasauau',
#   'hadjavechaudauwuna',
#   'hadjavesade',
#   'hadjeaedauwuneva',
#   'hadjedade',
#   'hadjedane',
#   'hadjedanethee',
#   'hadjeedauchaude',
#   'hadjeenechaudaune',
#   'hadjejaegauhadenenee',
#   'hadjejanaugudaune',
#   'hadjejanauhusanauau',
#   'hadjejenanauau',
#   'hadjejenanauwau',
#   'hadjenanathee',
#   'hadjenanauau',
#   'hadjenanaude',
#   'hadjenanauwau',
#   'hadjenanauwunauthee',
#   'hadjenanu',
#   'hadjenanuu',
#   'hadjenauahenith',
#   'hadjenauhaudauau',
#   'hadjenauuchaudenee',
#   'hadjenesedauwaunathee',
#   'hadjesedanauau',
#   'hadjethaugu',
#   'hadjevenade',
#   'hadjevenauthee',
#   'hadjewaunejedanith',
#   'hadjeyehauthee',
#   'hadnaadaudauyanusaa',
#   'hadnaadauthanauwau',
#   'hadnaade',
#   'hadnaaduuu',
#   'hadnaaeaudaa',
#   'hadnaaedaeyaunenena',
#   'hadnaaedauwauhade',
#   'hadnaaejaegauhade',
#   'hadnaaejaseseneheduu',
#   'hadnaaejenanauau',
#   'hadnaaenaugauyathee',
#   'hadnaaenauhauwauna',
#   'hadnaaenauwuaudenau',
#   'hadnaaene',
#   'hadnaaenehethauau',
#   'hadnaaesaanuna',
#   'hadnaaesedaunau',
#   'hadnaajauchuwuhane',
#   'hadnaane',
#   'hadnaasauau',
#   'hadnaasaunee',
#   'hadnaasedaunau',
#   'hadnaasedaunee',
#   'hadnaasehade',
#   'hadnaasejenanauwunana',
#   'hadnaasenehede',
#   'hadnaasenehethauau',
#   'hadnaasethajauaudaunana',
#   'hadnaasevasathaa',
#   'hadnaathade',
#   'hadnaathahedaunee',
#   'hadnadauyewu',
#   'hadnadenathajaunee',
#   'hadnadethaude',
#   'hadnaedauwauthauthee',
#   'hadnaedauwunana',
#   'hadnaedauwunaunith',
#   'hadnaede',
#   'hadnaenauau',
#   'hadnaenauwuna',
#   'hadnaenauwunethe',
#   'hadnajanede',
#   'hadnajawaudauau',
#   'hadnajawaudauwu',
#   'hadnanadaunethanethe',
#   'hadnanadede',
#   'hadnanasenedauau',
#   'hadnanaunauvaenana',
#   'hadnanedanede',
#   'hadnanedaudaunaude',
#   'hadnanedaunau',
#   'hadnanedauthee',
#   'hadnanesethajauaudaunana',
#   'hadnanethana',
#   'hadnanethauaunahedava',
#   'hadnanewauunauwunith',
#   'hadnasanauwaude',
#   'hadnasanavade',
#   'hadnasaunauthee',
#   'hadnasaunenau',
#   'hadnasedaa',
#   'hadnasenede',
#   'hadnathauaude',
#   'hadnathee',
#   'hadnauanauau',
#   'hadnauauchauau',
#   'hadnauauchaudaude',
#   'hadnauauchaudauna',
#   'hadnauauchaudaune',
#   'hadnauauchaunee',
#   'hadnauauchuu',
#   'hadnauauhaude',
#   'hadnauauva',
#   'hadnauauwunauauau',
#   'hadnauchaunena',
#   'hadnauchauvavathe',
#   'hadnauchauwaude',
#   'hadnauchuhajauwausauau',
#   'hadnauchuhanehede',
#   'hadnauchuhanenayauhaude',
#   'hadnauchunana',
#   'hadnauchuwuhathane',
#   'hadnauchuwuhauna',
#   'hadnaudauau',
#   'hadnaudauwuthajauna',
#   'hadnaudedaunathana',
#   'hadnaudethade',
#   'hadnaugaudanenee',
#   'hadnaugauhusenaasedaude',
#   'hadnaugauthuu',
#   'hadnauguhethee',
#   'hadnauguhudaunauna',
#   ...],
#  'breton': ['aba',
#   'abadaes',
#   'abalamour',
#   'abaoue',
#   'abardaes',
#   'abardaez',
#   'abars',
#   'abarz',
#   'abbe',
#   'abeg',
#   'abegou',
#   'abek',
#   'abenn',
#   'abiou',
#   'abnegantes',
#   'abortivus',
#   'abostol',
#   'abraham',
#   'abred',
#   'abrenuntio',
#   'abs',
#   'abscide',
#   'absolvo',
#   'absque',
#   'acceptabile',
#   'accidit',
#   'accipietis',
#   'acha',
#   'achalenn',
#   'achalese',
#   'achan',
#   'achano',
#   'achanoch',
#   'achanomnp',
#   'achanomp',
#   'achanon',
#   'achanout',
#   'achanta',
#   'achu',
#   'achue',
#   'achuet',
#   'achui',
#   'actou',
#   'adalek',
#   'adam',
#   'adarre',
#   'adeamus',
#   'adeo',
#   'adhuc',
#   'adimpleo',
#   'adjicien',
#   'adjicientur',
#   'adlennet',
#   'adolescentior',
#   'ador',
#   'adorasion',
#   'adoration',
#   'adoret',
#   'adori',
#   'adrenv',
#   'ael',
#   'aer',
#   'aerouant',
#   'aez',
#   'aferiou',
#   'affectione',
#   'affer',
#   'afferatis',
#   'afferiou',
#   'afferte',
#   'afflictionem',
#   'agnos',
#   'agreer',
#   'ahont',
#   'ahount',
#   'aket',
#   'aketus',
#   'aketuz',
#   'alaouret',
#   'alar',
#   'albukerque',
#   'alc',
#   'alchouez',
#   'alchuez',
#   'alegsandre',
#   'aleis',
#   'aleiz',
#   'alexandri',
#   'ali',
#   'alies',
#   'aliesa',
#   'aliesoc',
#   'aliesoch',
#   'aliessa',
#   'aliet',
#   'aliez',
#   'aliou',
#   'aliquid',
#   'aliud',
#   'all',
#   'allin',
#   'allum',
#   'alphonse',
#   'alter',
#   'altissimi',
#   'altum',
#   'alu',
#   'alusen',
#   'aluzen',
#   'aluzennou',
#   'alvoka',
#   'alvokad',
#   'alvokadez',
#   'ama',
#   'amabilia',
#   'aman',
#   'amantes',
#   'amare',
#   'amat',
#   'amateurs',
#   'amatores',
#   'amatur',
#   'ambroaz',
#   'ambroug',
#   'ambrouget',
#   'amc',
#   'amchoulou',
#   'ame',
#   'amen',
#   'amezeien',
#   'amezek',
#   'ami',
#   'amica',
#   'amicos',
#   'amicus',
#   'amjest',
#   'ampart',
#   'amplius',
#   'amprefaned',
#   'amser',
#   'amzer',
#   'amzivin',
#   'ana',
#   'anaon',
#   'anaou',
#   'anaoud',
#   'anaoudegez',
#   'anaout',
#   'anat',
#   'anathema',
#   'anavez',
#   'anavezan',
#   'anaveze',
#   'anavezemp',
#   'anavezen',
#   'anavezet',
#   'anavezient',
#   'anavezimp',
#   'anavezin',
#   'anavezit',
#   'anavezo',
#   'anavezomp',
#   'anavezont',
#   'anavoud',
#   'anavout',
#   'ancilla',
#   'aneval',
#   'anevaled',
#   'anez',
#   'anezan',
#   'anezhan',
#   'anezhi',
#   'anezho',
#   'anezo',
#   'angoni',
#   'anhezan',
#   'anhezo',
#   'anim',
#   'anima',
#   'animas',
#   'animi',
#   'anken',
#   'ankeniet',
#   'ankeniou',
#   'ankeniuz',
#   'ankenniet',
#   'ankou',
#   'ankounac',
#   'ankounach',
#   'ankounacha',
#   'ankounachaad',
#   'ankounachaat',
#   'ankounachafemp',
#   'ankounachait',
#   'ankounachaus',
#   'ankounacheat',
#   'ann',
#   'anna',
#   'anne',
#   'annezerien',
#   'annulum',
#   'antekrist',
#   'anter',
#   'antiochus',
#   'antronoz',
#   'anv',
#   'anvi',
#   'anvoed',
#   'anzao',
#   'anzav',
#   'aochou',
#   'aod',
#   'aogustin',
#   'aoled',
#   'aon',
#   'aont',
#   'aot',
#   'aotchou',
#   'aotennou',
#   'aoter',
#   'aoteriou',
#   'aotre',
#   'aotreal',
#   'aotro',
#   'aotronez',
#   'aotrou',
#   'aoualac',
#   'aoun',
#   'aour',
#   'aoutrou',
#   'aozas',
#   'aozet',
#   'aozit',
#   'apothiker',
#   'apparebit',
#   'appen',
#   'aprouvi',
#   'arabat',
#   'araog',
#   'araok',
#   'araozan',
#   'arbenn',
#   'arc',
#   'archant',
#   'archantiri',
#   'arched',
#   'archedi',
#   'archerien',
#   'arez',
#   'argila',
#   'argoat',
#   'arguet',
#   'arme',
#   'armel',
#   'armeou',
#   'armet',
#   'arne',
#   'arouden',
#   'arru',
#   'arvested',
#   'arvesti',
#   'arvor',
#   'arz',
#   'arzet',
#   'asames',
#   'ascendit',
#   'askouezo',
#   'askourn',
#   'aspedi',
#   'assa',
#   'asten',
#   'astenn',
#   'astennas',
#   'astenne',
#   'astenned',
#   'astennet',
#   'astennit',
#   'astenno',
#   'astuans',
#   'asvevet',
#   'atao',
#   'athen',
#   'ato',
#   'atriis',
#   'audiemus',
#   'audit',
#   'auditoires',
#   'audivit',
#   'augustin',
#   'auris',
#   'autem',
#   'autin',
#   'aux',
#   'auxilio',
#   'avad',
#   'aval',
#   'avarisded',
#   'ave',
#   'avec',
#   'avechou',
#   'avel',
#   'avelek',
#   'avelou',
#   'avi',
#   'avidi',
#   'aviel',
#   'avoallach',
#   'avons',
#   'avoualch',
#   'avoultriach',
#   'avoultriez',
#   'avril',
#   'awalc',
#   'awalch',
#   'awallc',
#   'awoalac',
#   'azalec',
#   'azalek',
#   'aze',
#   'azezet',
#   'azgoalchit',
#   'azioc',
#   'azioch',
#   'azioud',
#   'bad',
#   'badezet',
#   'badiziant',
#   'bado',
#   'bae',
#   'baea',
#   'baeit',
#   'baet',
#   'bag',
#   'baianed',
#   'baianet',
#   'bajenn',
#   'bak',
#   'baka',
#   'bal',
#   'balafen',
#   'balans',
#   'balanz',
#   'bale',
#   'baleet',
#   'baleit',
#   'balez',
#   'balf',
#   'bali',
#   'balthazar',
#   'baludenn',
#   'baniel',
#   'bank',
#   'bann',
#   'banna',
#   'bannalec',
#   'bano',
#   'baotred',
#   'baou',
#   'baouez',
#   'baour',
#   'baourentez',
#   'baper',
#   'bar',
#   'bara',
#   'barados',
#   'baradoz',
#   'bard',
#   'barderez',
#   'bardon',
#   'bardonaz',
#   'bardonnont',
#   'bardoun',
#   'bardouna',
#   'bardouni',
#   'bardouno',
#   'bardounot',
#   'bare',
#   'barea',
#   'bareet',
#   'bareo',
#   'bark',
#   'barlen',
#   'barn',
#   'barnabam',
#   'barnedigez',
#   'barner',
#   'barnerien',
#   'barnet',
#   'barr',
#   'barrabam',
#   'barrabas',
#   'barrad',
#   'barren',
#   'barres',
#   'barrez',
#   'barreziou',
#   'barrezma',
#   'barri',
#   'barrisionis',
#   'barrisioniz',
#   'barrissioniz',
#   'barrou',
#   'bartiaz',
#   'barzh',
#   'bask',
#   'bassion',
#   'bastored',
#   'baz',
#   'bazatead',
#   'bazen',
#   'bbeudeur',
#   'bea',
#   'beac',
#   'beach',
#   'beachour',
#   'beachourien',
#   'beadra',
#   'beati',
#   'beb',
#   'bec',
#   'bech',
#   'beche',
#   'beched',
#   'bechejou',
#   'becher',
#   'becherien',
#   'bechet',
#   'bechimp',
#   'bechit',
#   'bechomp',
#   'bed',
#   'bedan',
#   'bedaz',
#   'bede',
#   'beden',
#   'bedenn',
#   'bedennou',
#   'beder',
#   'bedi',
#   'bedma',
#   'bedo',
#   'bedomp',
#   'bedont',
#   'befe',
#   'beffe',
#   'beg',
#   'begou',
#   'behini',
#   'beilla',
#   'beleac',
#   'beleach',
#   'belec',
#   'beleg',
#   'beleget',
#   'beleien',
#   'belek',
#   'belial',
#   'bell',
#   'bella',
#   'bellaat',
#   'bellaer',
#   'bellaio',
#   'bellait',
#   'bemdez',
#   'bemnoz',
#   'bemp',
#   'ben',
#   'benag',
#   'benak',
#   'benduen',
#   'bene',
#   'benefaciendo',
#   'benerez',
#   'benignitate',
#   'benn',
#   'bennag',
#   'bennak',
#   'bennigen',
#   'benniget',
#   'bennos',
#   'bennou',
#   'bennoz',
#   'bense',
#   'bent',
#   'benv',
#   'benveg',
#   'beo',
#   'beoch',
#   'beorien',
#   'bep',
#   'bepred',
#   'ber',
#   'berad',
#   'bermision',
#   'bern',
#   'bernard',
#   'bernia',
#   'berniet',
#   'berniit',
#   'bernik',
#   'bero',
#   'berou',
#   'berr',
#   'berra',
#   'berrentez',
#   'berroc',
#   'berroch',
#   'bers',
#   'berseveranz',
#   'berseveri',
#   'bersoun',
#   'bervet',
#   'berz',
#   'beskerez',
#   'besketour',
#   'bet',
#   'beteg',
#   'betek',
#   'beth',
#   'bethleem',
#   'bethlehem',
#   'bethsaida',
#   'betra',
#   'beultrin',
#   'beur',
#   'beurachu',
#   'beurachuo',
#   'beurechuin',
#   'beurgreski',
#   'beurnetea',
#   'beut',
#   'beuta',
#   'beuz',
#   'beuzet',
#   'bev',
#   'beva',
#   'bevans',
#   'bevar',
#   'beven',
#   'bevet',
#   'bevez',
#   'bevit',
#   'bevomp',
#   'bez',
#   'beza',
#   'bezan',
#   'bezet',
#   'bezh',
#   'beziou',
#   'bezit',
#   'bezo',
#   'bezomp',
#   'biannoch',
#   'biban',
#   'bibit',
#   'bibitis',
#   'bign',
#   'bignad',
#   'bignat',
#   'bigne',
#   'bignfe',
#   'bigno',
#   'bihan',
#   'bihaneat',
#   'bihanik',
#   'bihanna',
#   'bihannat',
#   'bije',
#   'biken',
#   'bil',
#   'bili',
#   'bilierou',
#   'binijen',
#   'binijennou',
#   'binvidigez',
#   'binvidigeziou',
#   'binvidik',
#   'binvidikaat',
#   'biou',
#   'birou',
#   'birvidik',
#   'birviken',
#   'bis',
#   'biskoas',
#   'biskoaz',
#   'biskoazh',
#   'biz',
#   'bizin',
#   'bizou',
#   'bla',
#   'blad',
#   'blaneden',
#   'blank',
#   'blanten',
#   'blas',
#   'blasphemi',
#   'blaz',
#   'bleg',
#   'blege',
#   'bleget',
#   'bleina',
#   'bleis',
#   'bleiz',
#   'bleo',
#   'bleun',
#   'bleuniou',
#   'bleunv',
#   'bleunviou',
#   'bli',
#   'blij',
#   'blija',
#   'blijadur',
#   'blijadureziou',
#   'blijaduriou',
#   'blijaz',
#   'blije',
#   'blijent',
#   'blijo',
#   'blijomp',
#   'bloas',
#   'bloavez',
#   'bloavezh',
#   'bloavezhiou',
#   'bloaveziou',
#   'bloaz',
#   'blod',
#   'blouider',
#   'bloum',
#   'bloumm',
#   'bloun',
#   'blounsadur',
#   'blounset',
#   'blouz',
#   'bluen',
#   'boa',
#   'boagn',
#   'boan',
#   'boaniou',
#   'boanius',
#   'boaniuz',
#   'boanniuz',
#   'boazet',
#   'bobl',
#   'boblou',
#   'bod',
#   'boezan',
#   'boletennou',
#   'bolontez',
#   'boltred',
#   'bolz',
#   'bolzet',
#   'bom',
#   'bomm',
#   'bon',
#   'bonet',
#   'boni',
#   'bonitas',
#   'bono',
#   'bonum',
#   'bonus',
#   'bord',
#   'borgia',
#   'borz',
#   'bost',
#   'botez',
#   'bou',
#   'bouchad',
#   'boued',
#   'bouez',
#   'boueza',
#   'bouezan',
#   'bouezaz',
#   'boueze',
#   'bouezint',
#   'bouezit',
#   'bouezo',
#   'bouil',
#   'bouilladou',
#   'boulcha',
#   'bouliji',
#   'boull',
#   'boultren',
#   'boulzaz',
#   'bounereaz',
#   'bounerroch',
#   'bounner',
#   'bounneroc',
#   'bour',
#   'bourchassas',
#   'bouret',
#   'bourmen',
#   'bourmeno',
#   'bourmenont',
#   'bourreo',
#   'bourrevien',
#   'boutou',
#   'bouzar',
#   'bra',
#   'brank',
#   'brankou',
#   'brao',
#   'braoentez',
#   'bras',
#   'brasa',
#   'brasaat',
#   'brasan',
#   'brasoc',
#   'brasoch',
#   'brassa',
#   'brassoch',
#   'brava',
#   'braz',
#   'bre',
#   'breac',
#   'breach',
#   'bred',
#   'brein',
#   'breis',
#   'breiz',
#   'breizis',
#   'brema',
#   'bremaik',
#   'breman',
#   'brena',
#   'brenit',
#   'brenna',
#   'brennaz',
#   'brenv',
#   'brepari',
#   'breparit',
#   'breparo',
#   'breparomp',
#   'breparot',
#   'breset',
#   'bresk',
#   'brest',
#   'breton',
#   'bretonet',
#   'bretons',
#   'breu',
#   'breuder',
#   'breudeup',
#   'breudeur',
#   'breudreur',
#   'breur',
#   'breutaat',
#   'brez',
#   'breze',
#   'brezeg',
#   'brezegen',
#   'brezegennou',
#   'brezek',
#   'brezel',
#   'brezell',
#   'brezellour',
#   'brezhoneg',
#   'brezo',
#   'brezonek',
#   'brezounek',
#   'briadelez',
#   'briata',
#   'bried',
#   'briedelez',
#   'brieg',
#   'brinsez',
#   'bris',
#   'briz',
#   'brizit',
#   'bro',
#   'brofeted',
#   'broiou',
#   'bromesa',
#   'bromesaou',
#   'bromet',
#   'brometont',
#   'brophetet',
#   'brotestantet',
#   'brovidans',
#   'brovidanz',
#   'brud',
#   'bruded',
#   'brudet',
#   'bruzunachou',
#   'bruzunet',
#   'buan',
#   'buez',
#   'buezek',
#   'bugale',
#   'bugaleach',
#   'bugaligou',
#   'bugel',
#   'bugelik',
#   'buhan',
#   'buhanegez',
#   'buhanoc',
#   'buhez',
#   'bulluch',
#   'bur',
#   'burete',
#   'burzhud',
#   'burzud',
#   'burzudou',
#   'burzuduz',
#   'but',
#   'cabit',
#   'cadas',
#   'cadorbrezeg',
#   'cahredes',
#   'calicibus',
#   'calicis',
#   'canol',
#   'capiuntur',
#   'capturam',
#   'carcere',
#   'carnem',
#   'castel',
#   'castellin',
#   'catholik',
#   'causa',
#   'causam',
#   'cave',
#   'ccus',
#   'cdn',
#   'ceciderunt',
#   'celorum',
#   'celtique',
#   'certa',
#   'certen',
#   'ces',
#   'cest',
#   'cetis',
#   'cha',
#   'chabist',
#   'chabiten',
#   'chach',
#   'chacha',
#   'chachit',
#   'chaden',
#   'chadennet',
#   'chadennou',
#   'chaera',
#   'chaferiou',
#   'chaffomp',
#   'chal',
#   'chalanad',
#   'chaleou',
#   'chaleouner',
#   'chalese',
#   'chalfach',
#   'chalfe',
#   'chalfemp',
#   'chalfomp',
#   'challe',
#   'challed',
#   'challer',
#   'challimp',
#   'challin',
#   'challint',
#   'challit',
#   'challo',
#   'challomp',
#   'challont',
#   'challoud',
#   'challoudek',
#   'chalonou',
#   'chaloun',
#   'chaloup',
#   'chalur',
#   'chaluzen',
#   'chalv',
#   'chalvar',
#   'chalvaz',
#   'chalz',
#   'cham',
#   'chamezeien',
#   'chamzer',
#   'chan',
#   'chanaout',
#   'chanavezout',
#   'chankou',
#   'chankounachaont',
#   'channad',
#   'chanoine',
#   'chanoliou',
#   'chans',
#   'chantonier',
#   'chantonnier',
#   'chantvejou',
#   'chanver',
#   'chanz',
#   'chaon',
#   'chaorig',
#   'chaoud',
#   'chaout',
#   'chapel',
#   'char',
#   'charan',
#   'charantez',
#   'charantezusa',
#   'chare',
#   'chared',
#   'charet',
#   'charg',
#   'chargou',
#   'charimp',
#   'charint',
#   'charit',
#   'charlu',
#   'charo',
#   'charoud',
#   'charout',
#   'charpa',
#   'charr',
#   'chart',
#   'charus',
#   'charz',
#   'chas',
#   'chasas',
#   'chastel',
#   'chastell',
#   'chastenn',
#   'chastenno',
#   'chastiz',
#   'chastiza',
#   'chateau',
#   'chateaulin',
#   'chatekiz',
#   'chavaz',
#   'chavel',
#   'chaver',
#   'chavet',
#   'chavo',
#   'chavomp',
#   'chavot',
#   'chavoud',
#   'chazetennou',
#   'chechuan',
#   'ched',
#   'chedal',
#   'chedo',
#   'chef',
#   'chein',
#   'chel',
#   'chelennadurez',
#   'chelfe',
#   'chelfed',
#   'chelfemp',
#   'chelfet',
#   'chelfomp',
#   'chelfot',
#   'cheljen',
#   'chell',
#   'chellan',
#   'chellaz',
#   'chelle',
#   'cheller',
#   'chellez',
#   'chellimp',
#   'chellin',
#   'chellint',
#   'chellit',
#   'chello',
#   'chellomp',
#   'chellont',
#   'chellornp',
#   'chellot',
#   'chelloud',
#   'chelou',
#   'chelver',
#   'chem',
#   'chemennou',
#   'chemer',
#   'chemeret',
#   'chemerimp',
#   'chemerit',
#   'chemero',
#   'chemeront',
#   'chen',
#   'chench',
#   'chenchet',
#   'chenchit',
#   'chene',
#   'cheneb',
#   'chened',
#   'chenel',
#   'chenille',
#   'chent',
#   'chenta',
#   'chentja',
#   'chenver',
#   'cher',
#   'cherent',
#   'cherien',
#   'cherour',
#   'cherourien',
#   'cherru',
#   'cherrue',
#   'cherruo',
#   'cherzed',
#   'chesperanz',
#   ...],
#  'calo': ['aaron',
#   'abajines',
#   'abel',
#   'abias',
#   'abilina',
#   'abillaba',
#   'abillaban',
#   'abillad',
#   'abillado',
#   'abillando',
#   'abillar',
#   'abillara',
#   'abillaran',
#   'abillare',
#   'abillares',
#   'abillaria',
#   'abillaron',
#   'abillase',
#   'abillasen',
#   'abillel',
#   'abillela',
#   'abillelan',
#   'abillelas',
#   'abillele',
#   'abillelen',
#   'abilleli',
#   'abillelo',
#   'abillo',
#   'aborreceran',
#   'aborrecieren',
#   'abraham',
#   'abri',
#   'acabados',
#   'acabar',
#   'acabarla',
#   'acabo',
#   'acana',
#   'acaso',
#   'acechando',
#   'acechandole',
#   'acerca',
#   'achibes',
#   'achinose',
#   'acia',
#   'aclamado',
#   'acoi',
#   'acosado',
#   'acuerdo',
#   'acusado',
#   'acusais',
#   'acusandole',
#   'acusarle',
#   'acusarlo',
#   'adam',
#   'addi',
#   'ademas',
#   'adoracion',
#   'adulterio',
#   'aduque',
#   'afrentara',
#   'afrentare',
#   'afrentas',
#   'aguilas',
#   'ahondo',
#   'alabastro',
#   'alachaban',
#   'alachado',
#   'alachalareis',
#   'alachalen',
#   'alachar',
#   'alachara',
#   'alachare',
#   'alachareis',
#   'alachares',
#   'alacharla',
#   'alacharon',
#   'alache',
#   'alachela',
#   'alachelo',
#   'alacho',
#   'alas',
#   'alborotado',
#   'alegria',
#   'alendaba',
#   'alendaos',
#   'alendarnos',
#   'alendaron',
#   'alendela',
#   'alendelan',
#   'alendelo',
#   'alendo',
#   'alguna',
#   'alguno',
#   'aligatas',
#   'alimpiara',
#   'allanados',
#   'alonada',
#   'alpheo',
#   'altar',
#   'amangue',
#   'amares',
#   'amari',
#   'amarias',
#   'amaro',
#   'amenazo',
#   'aminadab',
#   'amolelais',
#   'amor',
#   'amos',
#   'ampiaba',
#   'ampiado',
#   'ampiaste',
#   'ampio',
#   'amularon',
#   'amule',
#   'ana',
#   'anacaba',
#   'anacado',
#   'anacados',
#   'anacar',
#   'anaco',
#   'anadio',
#   'anaquela',
#   'anaquele',
#   'anda',
#   'andiar',
#   'andiarmatejo',
#   'andre',
#   'andres',
#   'anduque',
#   'anglal',
#   'anguin',
#   'angusti',
#   'angustias',
#   'annas',
#   'anro',
#   'antela',
#   'antes',
#   'antorcha',
#   'anunciaba',
#   'anuncio',
#   'aotar',
#   'aparejad',
#   'aparejado',
#   'aparejar',
#   'aparte',
#   'apostoles',
#   'apretaba',
#   'apretura',
#   'aprieta',
#   'aprovechasarela',
#   'aqui',
#   'aquias',
#   'aquilon',
#   'aracata',
#   'aracateaba',
#   'aracaten',
#   'arachis',
#   'aram',
#   'araquela',
#   'araquelad',
#   'araquelaran',
#   'araquelaras',
#   'araquelen',
#   'araqueles',
#   'araquera',
#   'araquerada',
#   'araquerado',
#   'araquerados',
#   'araquerais',
#   'araquerando',
#   'araquerar',
#   'araqueraras',
#   'araquerare',
#   'araqueraron',
#   'araquerase',
#   'araquerela',
#   'araquerelan',
#   'araquerelas',
#   'araquero',
# ...
#   'mabait',
#   'mabawo',
#   'mabubuti',
#   'mabubuting',
#   'mabuti',
#   'mabuting',
#   'madali',
#   'madaling',
#   'madilim',
#   'madirinig',
#   'maestro',
#   'maewan',
#   'mag',
#   'magagawa',
#   'magagawang',
#   'magaling',
#   'magalit',
#   'magandang',
#   'magani',
#   'magara',
#   'magasawa',
#   'magbihis',
#   'magbuhat',
#   'magdaraan',
#   'magdaraya',
#   'maghahawak',
#   'magkaaninawa',
#   'magkagalit',
#   'magkainan',
#   'magkakainan',
#   'magkakawikaan',
#   'magkalamat',
#   'magkaligalig',
#   'magkangdadala',
#   'magkangmamayaw',
#   'magkano',
#   'magkasala',
#   'magkasalo',
#   'magkasigbay',
#   'magkatawanang',
#   'magkaulayao',
#   'magkipkip',
#   'magkita',
#   'maglagalag',
#   'maglan',
#   'magliguid',
#   'maglimos',
#   'maglinkod',
#   'magmula',
#   'magpapa',
#   'magpapahalata',
#   'magsasabi',
#   'magsisti',
#   'magsugal',
#   'magtakip',
#   'maguing',
#   'maguinoo',
#   'magulang',
#   'mahabang',
#   'mahalay',
#   'mahawa',
#   'mahinahong',
#   'mahinusay',
#   'mahirap',
#   'mai',
#   'maihabilin',
#   'mainit',
#   'maipalathala',
#   'maisaayos',
#   'maisipang',
#   'maitatanong',
#   'maitatawag',
#   'makaaasa',
#   'makaamoy',
#   'makabago',
#   'makabayan',
#   'makaganti',
#   'makahin',
#   'makakaban',
#   'makakaha',
#   'makakahalig',
#   'makakain',
#   'makakalakad',
#   'makakita',
#   'makalapit',
#   'makalayo',
#   'makapagaagno',
#   'makapagluto',
#   'makapiling',
#   'makasabi',
#   'makasasagot',
#   'makatagal',
#   'makatulong',
#   'makic',
#   'makikita',
#   'makiling',
#   'makita',
#   'malabis',
#   'malakas',
#   'malaki',
#   'malaking',
#   'malalapad',
#   'malalim',
#   'malamig',
#   'malapad',
#   'malapit',
#   'mali',
#   'maliban',
#   'maligayang',
#   'maliit',
#   'maliligo',
#   'maluang',
#   'malungkot',
#   'mamasdan',
#   'mamatay',
#   'mamaya',
#   'mamimili',
#   'man',
#   'manakbo',
#   'mananan',
#   'manang',
#   'mandin',
#   'mang',
#   'mangagamot',
#   'manggagawa',
#   'mangyari',
#   'mangyayari',
#   'manila',
#   'manok',
#   'mansanilia',
#   'mapa',
#   'mapag',
#   'mapagtantong',
#   'mapagturo',
#   'mapahamak',
#   'mapakinaban',
#   'mapalapit',
#   'mapalo',
#   'mapapadaan',
#   'mapapasalupa',
#   'maparam',
#   'mapasakatawan',
#   'mapupulang',
#   'marahil',
#   'marami',
#   'maraming',
#   'marunong',
#   'masakit',
#   'masama',
#   'masarap',
#   'masasalubong',
#   'masayod',
#   'masdan',
#   'masipag',
#   'masunod',
#   'mata',
#   'matagaltagal',
#   'matamo',
#   'matanda',
#   'matandang',
#   'matanto',
#   'matapos',
#   'matayog',
#   'matitira',
#   'matuid',
#   'matwa',
#   'mauna',
#   'maunawa',
#   'mauuli',
#   'may',
#   'mayari',
#   'maynila',
#   'mejor',
#   'membrete',
#   'membretes',
#   'meroon',
#   'mga',
#   'mimihi',
#   'minamainam',
#   'minarapat',
#   'minsa',
#   'minsan',
#   'minsang',
#   'moderna',
#   'mong',
#   'montesena',
#   'moy',
#   'mukha',
#   'mukos',
#   'mula',
#   'muli',
#   'muling',
#   'mumunti',
#   'muna',
#   'mungkahi',
#   'mungos',
#   'muni',
#   'munti',
#   'mura',
#   'musmos',
#   'naaalaala',
#   'nabalis',
#   'nabasa',
#   'nabibili',
#   'nabigo',
#   'nag',
#   'nagaansikot',
#   'nagbabago',
#   'nagbago',
#   'nagban',
#   'nagbibigay',
#   'nagbibilang',
#   'nagbubuga',
#   'nagbubuhat',
#   'nagdadasal',
#   'nagdaramdam',
#   'nagdasal',
#   'nagdasalan',
#   'nagdasan',
#   'nagdatin',
#   'naghahandaan',
#   'naghihintay',
#   'naghihinugang',
#   'nagkakaisa',
#   'nagkakalutlot',
#   'nagkakan',
#   'nagkakapalabasan',
#   'nagkakapustahan',
#   'nagkakasakit',
#   'nagkakataong',
#   'nagkakaumpok',
#   'nagkamit',
#   'nagkatawanan',
#   'nagkatipon',
#   'naglalan',
#   'nagluat',
#   'nagmakaamong',
#   'nagmungkahing',
#   'nagpaalam',
#   'nagpadala',
#   'nagpagakpakan',
#   'nagpahayag',
#   'nagpaluto',
#   'nagpapatakuil',
#   'nagpapatalo',
#   'nagpatuloy',
#   'nagsabi',
#   'nagsalin',
#   'nagsalita',
#   'nagsasaka',
#   'nagsiluhod',
#   'nagsimula',
#   'nagsipagpaalam',
#   'nagsiparoon',
#   'nagsisimula',
#   'nagsisipag',
#   'nagsubsob',
#   ...],
#  'welsh': ['aber',
#   'aberth',
#   'accmmt',
#   'acen',
#   'achos',
#   'achosi',
#   'achub',
#   'achubais',
#   'achubodd',
#   'achubwyd',
#   'adael',
#   'adar',
#   'adawaf',
#   'addaw',
#   'addef',
#   'addewid',
#   'addurn',
#   'addurno',
#   'adeg',
#   'aden',
#   'adenydd',
#   'aderyn',
#   'adgof',
#   'adgofion',
#   'adgyfodiad',
#   'adlais',
#   'adref',
#   'adrodd',
#   'adroddwr',
#   'adsain',
#   'adseinia',
#   'adseiniai',
#   'adseiniau',
#   'adseinio',
#   'adwaen',
#   'aed',
#   'ael',
#   'aeliau',
#   'aelwyd',
#   'aer',
#   'aeron',
#   'aeth',
#   'aethom',
#   'afael',
#   'afiaith',
#   'aflan',
#   'aflana',
#   'aflonyddu',
#   'afon',
#   'afradlon',
#   'agor',
#   'agorai',
#   'agorais',
#   'agored',
#   'agorodd',
#   'agos',
#   'ail',
#   'air',
#   'alar',
#   'alawon',
#   'all',
#   'allaf',
#   'allai',
#   'allan',
#   'allodd',
#   'allor',
#   'allwedd',
#   'allweddau',
#   'allwn',
#   'almanaciau',
#   'alw',
#   'amaethwr',
#   'ambell',
#   'amddifad',
#   'amddifaid',
#   'amdo',
#   'ameu',
#   'amgylch',
#   'amgylchiadol',
#   'amgylchynu',
#   'amharch',
#   'amheuaeth',
#   'amlwg',
#   'amount',
#   'amrant',
#   'amrantau',
#   'amser',
#   'anadl',
#   'anadlais',
#   'anadliad',
#   'anadlwn',
#   'anaearol',
#   'and',
#   'aneddau',
#   'anfarwol',
#   'anfarwoldeb',
#   'anfeidrol',
#   'anferth',
#   'anferthol',
#   'anfon',
#   'angau',
#   'angel',
#   'angen',
#   'angerddol',
#   'angeu',
#   'anghariad',
#   'anghelfydd',
#   'anghofio',
#   'anghofir',
#   'anghomon',
#   'anghydfod',
#   'angorai',
#   'angyles',
#   'angylion',
#   'anhapus',
#   'anhunanol',
#   'anian',
#   'anne',
#   'annedd',
#   'annghall',
#   'annibyniaeth',
#   'annuwiol',
#   'ant',
#   'anwyd',
#   'anwyl',
#   'anwylach',
#   'anwylaf',
#   'anwyliaid',
#   'anwylyd',
#   'aradr',
#   'araf',
#   'arall',
#   'arch',
#   'archoll',
#   'ardal',
#   'ardd',
#   'arddull',
#   'areithiwr',
#   'arfau',
#   'arfer',
#   'arfon',
#   'argaeau',
#   'argraffwyd',
#   'argreffir',
#   'arhosol',
#   'arhoswch',
#   'arian',
#   'arllwys',
#   'arllwysai',
#   'arlun',
#   'arnaf',
#   'arnat',
#   'arni',
#   'arno',
#   'arnynt',
#   'arogl',
#   'aros',
#   'arteithio',
#   'arthod',
#   'arthur',
#   'aruthrol',
#   'arwain',
#   'arwest',
#   'arwr',
#   'arwyddair',
#   'asgwrn',
#   'ataf',
#   'atal',
#   'atalfa',
#   'ateb',
#   'ateba',
#   'atebai',
#   'ategu',
#   'athroniaeth',
#   'athrylith',
#   'ati',
#   'ato',
#   'atyniad',
#   'aur',
#   'awel',
#   'awelon',
#   'awen',
#   'awgrym',
#   'awn',
#   'awr',
#   'awrlais',
#   'awst',
#   'awydd',
#   'awyr',
#   'awyrgylch',
#   'baban',
#   'babanod',
#   'babi',
#   'bac',
#   'bach',
#   'bachan',
#   'bachgen',
#   'back',
#   'bad',
#   'badau',
#   'bae',
#   'baeh',
#   'bai',
#   'balchder',
#   'baldorddi',
#   'ban',
#   'baner',
#   'banerau',
#   'banllef',
#   'bannau',
#   'bara',
#   'bardd',
#   'barfog',
#   'barn',
#   'barnu',
#   'barod',
#   'bartiaeth',
#   'basiai',
#   'basient',
#   'basio',
#   'bawb',
#   'bechadur',
#   'bechgyn',
#   'bechod',
#   'bechodau',
#   'bedd',
#   'beddau',
#   'beddrod',
#   'bedolau',
#   'bedwar',
#   'bedydd',
#   'begwn',
#   'beiau',
#   'beidiai',
#   'beilchion',
#   'beipan',
#   'beirdd',
#   'bell',
#   'bellach',
#   'bellder',
#   'bellderau',
#   'ben',
#   'bena',
#   'benaduriaid',
#   'bencerdd',
#   'benchwiban',
#   'bendefig',
#   'bendefigion',
#   'bendith',
#   'bendithion',
#   'benfro',
#   'benhillion',
#   'bennaf',
#   'bennau',
#   'bennill',
#   'benthyca',
#   'bentref',
#   'benyr',
#   'ber',
#   'beraidd',
#   'berchen',
#   'bererindod',
#   'berfa',
#   'berffaith',
#   'berlau',
#   'berthnasau',
#   'berthynas',
#   'berwi',
#   'berygl',
#   'beswch',
#   'besychai',
#   'beth',
#   'bethau',
#   'bethma',
#   'beudy',
#   'beunydd',
#   'bia',
#   'bicell',
#   'bicellau',
#   'big',
#   'bla',
#   'blaen',
#   'blaenor',
#   'blant',
#   'blanwyd',
#   'blas',
#   'blastro',
#   'blaw',
#   'blawd',
#   'ble',
#   'bleidiau',
#   'blentyn',
#   'blewyn',
#   'blin',
#   'blinderus',
#   'blino',
#   'blodau',
#   'blodeuglwm',
#   'blodeuo',
#   'blodionos',
#   'blodyn',
#   'bloedd',
#   'bloeddiadau',
#   'bloeddiwn',
#   'blu',
#   'bluf',
#   'bluo',
#   'blwydd',
#   'blwyddau',
#   'bob',
#   'bobl',
#   'bobol',
#   'boced',
#   'boch',
#   'bochau',
#   'bod',
#   'boddhad',
#   'boed',
#   'bon',
#   'boneddwyr',
#   'bones',
#   'boni',
#   'bonnet',
#   'bopeth',
#   'borau',
#   'bore',
#   'borthi',
#   'bosibl',
#   'bosworth',
#   'botel',
#   'botymau',
#   'brad',
#   'bradus',
#   'bradychu',
#   'braf',
#   'brag',
#   'braidd',
#   'brain',
#   'brau',
#   'braw',
#   'brawd',
#   'brawf',
#   'brefiadau',
#   'brenhines',
#   'brenhinoedd',
#   'brenhinol',
#   'brenin',
#   'bresennol',
#   'breuddwyd',
#   'breuddwydiais',
#   'breuddwydio',
#   'breuddwydion',
#   'bri',
#   'briaill',
#   'briddellau',
#   'brif',
#   'brinley',
#   'briod',
#   'briodas',
#   'briodferch',
#   'briodi',
#   'briododd',
#   'britannia',
#   'britho',
#   'briw',
#   'briwedig',
#   'briwo',
#   'bro',
#   'broc',
#   'brofi',
#   'bron',
#   'bronnau',
#   'brown',
#   'brudd',
#   'bruddaidd',
#   'brwydrau',
#   'brwyn',
#   'brycheiniog',
#   'bryd',
#   'brydain',
#   'brydeiniaid',
#   'brydferthach',
#   'brydferthwch',
#   'brydiau',
#   'brydnawnddydd',
#   'brydweddol',
#   'bryn',
#   'bryniau',
#   'brynnu',
#   'brynsoch',
#   'brysiwch',
#   'brytanaidd',
#   'brython',
#   'buasai',
#   'buddug',
#   'buddugoliaeth',
#   'bum',
#   'buom',
#   'bur',
#   'bwa',
#   'bwl',
#   'bwlch',
#   'bwndel',
#   'bwrdd',
#   'bwthyn',
#   'bwyllus',
#   'bwynt',
#   'bwys',
#   'bwysau',
#   'bwyso',
#   'bychain',
#   'bychan',
#   'byd',
#   'bydd',
#   'byddai',
#   'byddo',
#   'byliaid',
#   'bymtheg',
#   'bynnag',
#   'byron',
#   'byrr',
#   'byrth',
#   'bys',
#   'bysedd',
#   'byth',
#   'bythol',
#   'bytholfyd',
#   'byw',
#   'bywyd',
#   'cabolwyd',
#   'cadarn',
#   'caddug',
#   'cadw',
#   'cadwant',
#   'cadwn',
#   'cae',
#   'cael',
#   'caergwydion',
#   'caf',
#   'cafodd',
#   'cai',
#   'caiff',
#   'caled',
#   'call',
#   'calon',
#   'calonnau',
#   'cam',
#   'cambrian',
#   'can',
#   'cana',
#   'canai',
#   'caneuon',
#   'canfod',
#   'cangen',
#   'canghennau',
#   'canig',
#   'canodd',
#   'canol',
#   'canolbwynt',
#   'cant',
#   'cantab',
#   'cantawd',
#   'canu',
#   'canwn',
#   'capten',
#   'car',
#   'caraf',
#   'carai',
#   'carew',
#   'carey',
#   'cariad',
#   'cariadus',
#   'cario',
#   'carodd',
#   'cartref',
#   'cartrefle',
#   'caru',
#   'carwriaeth',
#   'cas',
#   'casglu',
#   'casglwn',
#   'catherine',
#   'cau',
#   'cawn',
#   'cedyrn',
#   'cefais',
#   'cefn',
#   'cei',
#   'ceid',
#   'ceidwad',
#   'ceiliogod',
#   'ceir',
#   'ceisia',
#   'ceisio',
#   'celwydd',
#   'celwyddau',
#   'cenad',
#   'cenedl',
#   'cenedlaethol',
#   'cenfydd',
#   'cenhinen',
#   'cenin',
#   'cenir',
#   'cenllysg',
#   'cennad',
#   'cenwch',
#   'cerdd',
#   'cerddediad',
#   'cerddi',
#   'cerddorion',
#   'cerrig',
#   'ces',
#   'cestyll',
#   'cewch',
#   'cewri',
#   'cha',
#   'chadw',
#   'chael',
#   'chai',
#   'chais',
#   'chalon',
#   'cham',
#   'chan',
#   'chanai',
#   'chanddi',
#   'chaniadau',
#   'chanol',
#   'chanu',
#   'chanwch',
#   'chariad',
#   'chariadau',
#   'chario',
#   'charth',
#   'chartref',
#   'charu',
#   'chau',
#   'chauais',
#   'chawn',
#   'chawsant',
#   'chefn',
#   'cheidw',
#   'cheir',
#   'cheisiai',
#   'chenais',
#   'chenedl',
#   'cherddor',
#   'cherfier',
#   'chledd',
#   'chleddyf',
#   'chlefyd',
#   'chlercod',
#   'chlocs',
#   'chlod',
#   'chlwy',
#   'chlwyf',
#   'chlywai',
#   'chlywir',
#   'chlywodd',
#   'chlywsant',
#   'chochi',
#   'chodai',
#   'choder',
#   'chodi',
#   'chododd',
#   'choed',
#   'chofiai',
#   'chofio',
#   'chol',
#   'cholli',
#   'chorff',
#   'chorn',
#   'choron',
#   'chreda',
#   'chrefydd',
#   'chreigiau',
#   'chrio',
#   'chroesi',
#   'chrwydro',
#   'chryf',
#   'chryma',
#   'chrymu',
#   'chrynnai',
#   'chuddia',
#   'chur',
#   'churai',
#   'churiad',
#   'chwaer',
#   'chwaeth',
#   'chwaith',
#   'chwalu',
#   'chwardda',
#   'chwarddai',
#   'chwardded',
#   'chwarddwn',
#   'chwarelwr',
#   'chwarelwyr',
#   'chwareu',
#   'chwe',
#   'chwech',
#   'chwedl',
#   'chwedlau',
#   'chwef',
#   'chwerthin',
#   'chwerw',
#   'chwery',
#   'chwi',
#   'chwiban',
#   'chwifio',
#   'chwifiwn',
#   'chwil',
#   'chwilio',
#   'chwim',
#   'chwith',
#   'chwpl',
#   'chwyd',
#   'chwydda',
#   'chwyddedig',
#   'chwyddo',
#   'chwyfio',
#   'chwyn',
#   'chwyrnai',
#   'chwys',
#   'chwysu',
#   'chwytha',
#   'chwyther',
#   'chwythu',
#   'chyda',
#   'chydig',
#   'chydymdeimlad',
#   'chyffro',
#   'chyfoeth',
#   'chylch',
#   'chymdeithas',
#   'chymro',
#   'chymru',
#   'chysgod',
#   'chysgu',
#   'ciamfa',
#   'ciamu',
#   'cianol',
#   'ciarag',
#   'ciariad',
#   'ciaws',
#   'cilgwth',
#   'cilgwthiodd',
#   'ciliai',
#   'cilio',
#   'cinio',
#   'cipiodd',
#   'cipiwyd',
#   'cistiau',
#   'claddu',
#   'claddwyd',
#   'claear',
#   'clau',
#   'clecian',
#   'cledd',
#   'cleddyf',
#   'cleddyfau',
#   'clefyd',
#   'clir',
#   'clirio',
#   'cliriwch',
#   'cloch',
#   'clod',
#   'clodd',
#   'clodfawr',
#   'clogwyn',
#   'clogwyni',
#   'clomen',
#   'clust',
#   'clwy',
#   'clwyfo',
#   'clychau',
#   'clyd',
#   'clyw',
#   'clywaf',
#   'clywais',
#   'clywch',
#   'clywed',
#   'clywir',
#   'clywodd',
#   'cnau',
#   'cneuen',
#   'cnocio',
#   'cnul',
#   'codi',
#   'codwn',
#   'coed',
#   'coel',
#   'cof',
#   'coffadwriaeth',
#   'cofiaf',
#   'cofio',
#   'cofiwch',
#   'colli',
#   'colofn',
#   'colofnau',
#   'cooper',
#   'corachod',
#   'corn',
#   'cornel',
#   'coron',
#   'coronwyd',
#   'corwynt',
#   'crach',
#   'crafu',
#   'craig',
#   'cread',
#   'creda',
#   'credais',
#   'credu',
#   'crefydd',
#   'creigiau',
#   'creigydd',
#   'creulon',
#   'cri',
#   'crist',
#   'croch',
#   'crochan',
#   'croes',
#   'croesaw',
#   'croew',
#   'crogi',
#   'crogwn',
#   'crud',
#   'crwn',
#   'crwtyn',
#   'crwydro',
#   'cry',
#   'crydd',
#   'cryf',
#   'cryn',
#   'crynna',
#   'crynno',
#   'cudd',
#   'cun',
#   'cur',
#   'curai',
#   'curiad',
#   'curiadau',
#   'curo',
#   'cusanau',
#   'cusanu',
#   'cwbl',
#   'cweryl',
#   'cwerylon',
#   'cwestiwn',
#   'cwlwm',
#   'cwm',
#   'cwmwl',
#   'cwn',
#   'cwnni',
#   'cwpan',
#   'cwrdd',
#   'cwrddais',
#   'cwrlid',
#   'cwsg',
#   'cwyd',
#   'cwympa',
#   'cwynai',
#   'cychwynais',
#   'cychwynnai',
#   'cychwynnais',
#   'cyd',
#   'cydalarwn',
#   'cydfyw',
#   'cydgan',
#   'cydrhwng',
#   'cyduna',
#   'cydweithiwn',
#   'cydweithwyr',
#   'cydwybod',
#   'cydwylai',
#   'cydwylo',
#   'cydymdeimlad',
#   'cydysgwyd',
#   'cyfaill',
#   'cyfan',
#   'cyfansoddwyd',
#   'cyfeillgarwch',
#   'cyfeillion',
#   'cyffredin',
#   'cyffwrdd',
#   'cyfieithwch',
#   'cyfodi',
#   'cyfrif',
#   'cyfrol',
#   'cyfryw',
#   'cyhoeddi',
#   'cyhoeddir',
#   'cyhyd',
#   'cylch',
#   'cylchu',
#   'cyll',
#   'cymaint',
#   'cymdogion',
#   'cymer',
#   'cymerai',
#   'cymeryd',
#   'cymoedd',
#   'cymraeg',
#   'cymreig',
#   'cymro',
#   'cymru',
#   'cymry',
#   'cymyl',
#   'cymysg',
#   'cyn',
#   'cynan',
#   'cyngor',
#   'cynhadledd',
#   'cynhaeaf',
#   'cynhesu',
#   'cynhulliadau',
#   'cynhyrfiad',
#   'cynllun',
#   'cynnes',
#   'cynneu',
#   'cynnyg',
#   'cyntaf',
#   'cynygiodd',
#   'cyrhaeddyd',
#   'cyrn',
#   'cyrraedd',
#   'cysegr',
#   'cysgod',
#   'cysgodion',
#   'cystal',
#   'cystudd',
#   'cywair',
#   'cywir',
#   'dacw',
#   'dad',
#   'dadau',
#   'dadganu',
#   'dadweinied',
#   'daear',
#   'daen',
#   'daenwn',
#   'daer',
#   'daeru',
#   'daeth',
#   'dafarn',
#   'daflodd',
#   'dafnau',
#   'dafod',
#   'dafodau',
#   'dafydd',
#   'dagrau',
#   'dail',
#   'dair',
#   'daith',
#   'dal',
#   'dalen',
#   'damwain',
#   'dan',
#   'danghosir',
#   'dangos',
#   'danio',
#   'danllwyth',
#   'dannau',
#   'dano',
#   'danod',
#   'darfai',
#   'darfod',
#   'darfu',
#   'darfyddant',
#   'darllen',
#   'darllennodd',
#   'darllenwyd',
#   'darlun',
#   'darluniau',
#   'darlunio',
#   'darnio',
#   'daro',
#   'datodai',
#   'dau',
#   'davies',
#   'daw',
#   'dawel',
#   'dawn',
#   'dawnsio',
#   'dda',
#   'ddadglodd',
#   'ddadgymalu',
#   'ddaear',
#   'ddaeth',
#   'ddaethai',
#   'ddaethum',
#   'ddagrau',
#   'ddail',
#   'ddaint',
#   'ddalen',
#   'ddalennau',
#   'ddaliais',
#   'ddalio',
#   'ddall',
#   'ddant',
#   'ddarfu',
#   'ddarllen',
#   'ddarlunio',
#   'ddarnau',
#   'ddau',
#   'ddaw',
#   'ddawn',
#   'ddawnus',
#   'ddechreu',
#   'ddechreusant',
#   'ddedwydd',
#   'ddedwyddwch',
#   'ddeffro',
#   'ddeffroai',
#   'ddefodan',
#   'ddeg',
#   'ddeheu',
#   'ddeii',
#   'ddeiliaid',
#   'ddelfrydau',
#   'ddelir',
#   'ddelw',
#   'dderwen',
#   'ddeuwch',
#   'ddewr',
#   'ddewrder',
#   'ddewrion',
#   'ddi',
#   'ddiareb',
#   'ddiau',
#   'ddiddan',
#   'ddideimlad',
#   'ddieithr',
#   'ddiffodd',
#   'ddiffygio',
#   'ddiflannodd',
#   'ddiflas',
#   'ddifraw',
#   'ddifri',
#   'ddifyr',
#   'ddig',
#   'ddigio',
#   'ddiglwyf',
#   'ddigoll',
#   'ddigon',
#   'ddigonedd',
#   'ddigrifwch',
#   'ddigyffro',
#   'ddillad',
#   'ddilyn',
#   'ddim',
#   'ddinam',
#   'ddinas',
#   'ddinistr',
#   'ddiniwaid',
#   'ddiod',
#   'ddioed',
#   'ddioedi',
#   'ddiogel',
#   'ddiogi',
#   'ddiolch',
#   'ddiolchgarwch',
#   'ddirnad',
#   'ddirywiedig',
#   'ddisglair',
#   'ddisgwyl',
#   'ddisymwth',
#   'ddiweddaf',
#   'ddiwrnod',
#   'ddiystyr',
#   'ddn',
#   'ddod',
#   'ddoe',
#   'ddoeth',
#   'ddofn',
#   'ddoi',
#   'ddol',
#   'ddolen',
#   'ddolurus',
#   'ddoniol',
#   'ddor',
#   'ddraenen',
#   'ddraig',
#   'ddreigiau',
#   'ddrwg',
#   'ddrws',
#   'ddrych',
#   'ddrychinog',
#   'ddrycin',
#   'ddrylliodd',
#   'ddu',
#   'dduaf',
#   'ddur',
#   'dduw',
#   'dduwch',
#   'ddwed',
#   'ddwedai',
#   'ddwedent',
#   'ddwedodd',
#   'ddwedsoch',
#   'ddwedyd',
#   ...]}

# %%
#store dict as json
import json

# %%
with open('dictionnaries.json', 'w') as fp:
    json.dump(languages_dict, fp, sort_keys=True, indent=4)

# %%
with open('dictionnaries.json', 'r') as fp:
    data = json.load(fp)
